# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import KFold, train_test_split
from sklearn.metrics import precision_recall_fscore_support,roc_auc_score
import lightgbm as lgb
import joblib
import warnings
warnings.filterwarnings("ignore")
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
from sklearn.metrics import recall_score
from functools import reduce

# %%
list_year = ['2021','2020','2019','2018','2017','2016','2015','2014']
accuracy_list = []
auc_list = []
recall_list = []

def Average(lst):
    return reduce(lambda a, b: a + b, lst) / len(lst)

for year in list_year:
    print('############################################################################')
    print('year'+ year + '\n')
    df_ratios = pd.read_csv(year+'.csv')
    #df_ratios.head()

    # Display the structure
    #df_ratios.info()

    # Normalization
    from sklearn import preprocessing
    min_max_scaler = preprocessing.MinMaxScaler()
    for i in df_ratios.columns[3:-12]:
        df_ratios[i] = min_max_scaler.fit_transform(df_ratios[[i]].to_numpy())*1000
        df_ratios[i] = df_ratios[i].apply(lambda x: np.log10(x + 0.01))
        ### this normalization is arbitrary, but should put all nos. in comparable basis of the same magnitude - can see the
        ###   describe statistics below
    #df_ratios.head(10)

    df_ratios_new=df_ratios

    X = df_ratios_new.iloc[:,3:-1]
    y = df_ratios_new.iloc[:,-1]

    Train, Test = train_test_split(df_ratios_new, test_size=0.4, random_state=43)
    X_train, y_train = Train.iloc[:,3:-1], Train.iloc[:,-1]
    X_test, y_test = Test.iloc[:,3:-1], Test.iloc[:,-1]
    #print(y_test.dtype)
    #print(y_test)

    #y_test.shape[0]

    #len(df_ratios_new)

    #X_train.head()

    # hyper parameter setting
    #2^(max_depth) for num_leaves
    #huge number prevents overfitting.
    params = {'num_leaves':491,
              'min_data_in_leaf':106,
              'objective':'binary',# binary classification
              'max_depth':-1, # no limit
              'boosting_type':'gbdt',#'dart','goss','rf'
              'metric':'auc',
              'verbosity':-1, 
              'random_state':42
    }

    # to save feature importance
    feature_importance = pd.DataFrame(index=None)

    feature_importance['features'] = X_train.columns

    feature_importance

    # k fold cross validation
    folds = KFold(n_splits=5)

    splits = folds.split(X,y)

    next(iter(splits))

    best_auc = 0
    best_model = None

    for k,(train_indices, val_indices) in enumerate(splits):
        #print(f'{k}th fold')
        X_train, X_val = X.iloc[train_indices], X.iloc[val_indices]
        y_train, y_val = y.iloc[train_indices], y.iloc[val_indices]

        train_dataset = lgb.Dataset(X_train,label=y_train)
        val_dataset = lgb.Dataset(X_val,label=y_val)

        lgb_model = lgb.train(
            params=params,
            train_set = train_dataset,
            #number of boosting iterations.
            num_boost_round = 10000,
            valid_sets = val_dataset,
            valid_names = 'validation',
            early_stopping_rounds = 50,
        )
        feature_importance[f'fold_{k+1}'] = lgb_model.feature_importance()

        y_val_pred = lgb_model.predict(X_val)

        roc_auc = roc_auc_score(y_val,y_val_pred)
        #print(f'fold {k+1} | AUC_ROC: {roc_auc *100}%')

        if roc_auc > best_auc:
            best_auc = roc_auc
            best_model = lgb_model

    #best_auc

    #feature_importance.head()

    feature_importance['average'] = feature_importance[[f'fold_{k+1}' for k in range (folds.n_splits-1)]].mean(axis=1)

    # visualize top 50 features
    plt.figure(figsize=(16,16))
    sns.barplot(data=feature_importance.sort_values(by='average',ascending=False).head(50),
               x='average',
               y='features')
    plt.title(f'top 50 features importances over {folds.n_splits-1} folds average.')
    
    print('best roc_auc:', best_auc)

    Train, Test = train_test_split(df_ratios_new, test_size=0.4, random_state=42)
    X_train, y_train = Train.iloc[:,3:-1], Train.iloc[:,-1]
    X_test, y_test = Test.iloc[:,3:-1], Test.iloc[:,-1]
    from sklearn.metrics import roc_auc_score
    from sklearn.metrics import roc_curve
    lgb_roc_auc = roc_auc_score(y_test, best_model.predict(X_test))
    lgb_roc_auc_train = roc_auc_score(y_train, best_model.predict(X_train))
    fpr, tpr, thresholds = roc_curve(y_test, best_model.predict(X_test))
    fpr_train, tpr_train, thresholds_train = roc_curve(y_train, best_model.predict(X_train))
    plt.figure()
    plt.plot(fpr, tpr, label='LGBM_test (area = %0.2f)' % lgb_roc_auc)
    plt.plot(fpr_train, tpr_train, label='LGBM_train (area = %0.2f)' % lgb_roc_auc_train)
    plt.plot([0, 1], [0, 1],'r--')
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('Receiver operating characteristic')
    plt.legend(loc="lower right")
    plt.savefig('LGB_ROC')
    plt.show()

    from sklearn.metrics import accuracy_score
    y_pred = best_model.predict(X_test)
    predictions = [round(value) for value in y_pred]
    # evaluate predictions
    accuracy = accuracy_score(y_test, predictions)
    print("Accuracy: %.2f%%" % (accuracy * 100.0))
    accuracy_list.append(accuracy * 100.0)
    auc_list.append(best_auc)
    
    from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
    import sklearn.metrics as metrics
    confusion_matrix = confusion_matrix(y_test, predictions)
    cm_display = metrics.ConfusionMatrixDisplay(confusion_matrix = confusion_matrix, display_labels = [0, 1])
    cm_display.plot()
    plt.show()
    print(classification_report(y_test, predictions))
    recallScore = recall_score(y_test, predictions)
    recall_list.append(recallScore)        
    print('############################################################################')

print('Accuracy 2021 to 2014', accuracy_list)
print('')
print('')
print('AUC 2021 to 2014', auc_list)  
print('')
print('')
average_recall = Average(recall_list)
print('recall score 2021 to 2014', recall_list)
print('')
print('')
print('average recall of 1: ', average_recall)
# Out:
# ############################################################################
# year2021
#
# [1]	validation's auc: 0.853118
# Training until validation scores don't improve for 50 rounds
# [2]	validation's auc: 0.85488
# [3]	validation's auc: 0.869958
# [4]	validation's auc: 0.876588
# [5]	validation's auc: 0.877462
# [6]	validation's auc: 0.877754
# [7]	validation's auc: 0.880669
# [8]	validation's auc: 0.883502
# [9]	validation's auc: 0.885873
# [10]	validation's auc: 0.884326
# [11]	validation's auc: 0.887533
# [12]	validation's auc: 0.888598
# [13]	validation's auc: 0.889226
# [14]	validation's auc: 0.890525
# [15]	validation's auc: 0.889828
# [16]	validation's auc: 0.891235
# [17]	validation's auc: 0.891463
# [18]	validation's auc: 0.891102
# [19]	validation's auc: 0.889644
# [20]	validation's auc: 0.891083
# [21]	validation's auc: 0.891121
# [22]	validation's auc: 0.892762
# [23]	validation's auc: 0.893447
# [24]	validation's auc: 0.893332
# [25]	validation's auc: 0.894004
# [26]	validation's auc: 0.894625
# [27]	validation's auc: 0.894663
# [28]	validation's auc: 0.894372
# [29]	validation's auc: 0.895411
# [30]	validation's auc: 0.895424
# [31]	validation's auc: 0.895551
# [32]	validation's auc: 0.896121
# [33]	validation's auc: 0.895678
# [34]	validation's auc: 0.895792
# [35]	validation's auc: 0.895234
# [36]	validation's auc: 0.894651
# [37]	validation's auc: 0.894587
# [38]	validation's auc: 0.893814
# [39]	validation's auc: 0.893687
# [40]	validation's auc: 0.893725
# [41]	validation's auc: 0.893294
# [42]	validation's auc: 0.893916
# [43]	validation's auc: 0.893371
# [44]	validation's auc: 0.893928
# [45]	validation's auc: 0.894118
# [46]	validation's auc: 0.894182
# [47]	validation's auc: 0.894486
# [48]	validation's auc: 0.894689
# [49]	validation's auc: 0.894068
# [50]	validation's auc: 0.894638
# [51]	validation's auc: 0.894892
# [52]	validation's auc: 0.894942
# [53]	validation's auc: 0.89389
# [54]	validation's auc: 0.893725
# [55]	validation's auc: 0.894182
# [56]	validation's auc: 0.893941
# [57]	validation's auc: 0.894296
# [58]	validation's auc: 0.893371
# [59]	validation's auc: 0.892635
# [60]	validation's auc: 0.892496
# [61]	validation's auc: 0.892141
# [62]	validation's auc: 0.892559
# [63]	validation's auc: 0.892762
# [64]	validation's auc: 0.89223
# [65]	validation's auc: 0.892572
# [66]	validation's auc: 0.892204
# [67]	validation's auc: 0.892534
# [68]	validation's auc: 0.891507
# [69]	validation's auc: 0.89133
# [70]	validation's auc: 0.893218
# [71]	validation's auc: 0.893054
# [72]	validation's auc: 0.893231
# [73]	validation's auc: 0.893472
# [74]	validation's auc: 0.893852
# [75]	validation's auc: 0.893776
# [76]	validation's auc: 0.893865
# [77]	validation's auc: 0.894562
# [78]	validation's auc: 0.894625
# [79]	validation's auc: 0.89493
# [80]	validation's auc: 0.894258
# [81]	validation's auc: 0.894334
# [82]	validation's auc: 0.894296
# Early stopping, best iteration is:
# [32]	validation's auc: 0.896121
# [1]	validation's auc: 0.848951
# Training until validation scores don't improve for 50 rounds
# [2]	validation's auc: 0.856973
# [3]	validation's auc: 0.857741
# [4]	validation's auc: 0.857384
# [5]	validation's auc: 0.853595
# [6]	validation's auc: 0.859452
# [7]	validation's auc: 0.862019
# [8]	validation's auc: 0.861888
# [9]	validation's auc: 0.862735
# [10]	validation's auc: 0.866663
# [11]	validation's auc: 0.873202
# [12]	validation's auc: 0.877069
# [13]	validation's auc: 0.879653
# [14]	validation's auc: 0.883922
# [15]	validation's auc: 0.886803
# [16]	validation's auc: 0.889264
# [17]	validation's auc: 0.891604
# [18]	validation's auc: 0.891866
# [19]	validation's auc: 0.892128
# [20]	validation's auc: 0.894467
# [21]	validation's auc: 0.895995
# [22]	validation's auc: 0.89596
# [23]	validation's auc: 0.896746
# [24]	validation's auc: 0.897374
# [25]	validation's auc: 0.898911
# [26]	validation's auc: 0.899364
# [27]	validation's auc: 0.89898
# [28]	validation's auc: 0.899591
# [29]	validation's auc: 0.899626
# [30]	validation's auc: 0.900045
# [31]	validation's auc: 0.900849
# [32]	validation's auc: 0.90125
# [33]	validation's auc: 0.900953
# [34]	validation's auc: 0.900971
# [35]	validation's auc: 0.901093
# [36]	validation's auc: 0.901355
# [37]	validation's auc: 0.901058
# [38]	validation's auc: 0.900971
# [39]	validation's auc: 0.902193
# [40]	validation's auc: 0.902821
# [41]	validation's auc: 0.902315
# [42]	validation's auc: 0.903502
# [43]	validation's auc: 0.903659
# [44]	validation's auc: 0.904131
# [45]	validation's auc: 0.903013
# [46]	validation's auc: 0.903659
# [47]	validation's auc: 0.90537
# [48]	validation's auc: 0.905999
# [49]	validation's auc: 0.90544
# [50]	validation's auc: 0.90558
# [51]	validation's auc: 0.906715
# [52]	validation's auc: 0.906697
# [53]	validation's auc: 0.907291
# [54]	validation's auc: 0.907832
# [55]	validation's auc: 0.907937
# [56]	validation's auc: 0.907535
# [57]	validation's auc: 0.907535
# [58]	validation's auc: 0.907047
# [59]	validation's auc: 0.907169
# [60]	validation's auc: 0.907885
# [61]	validation's auc: 0.907169
# [62]	validation's auc: 0.907501
# [63]	validation's auc: 0.907762
# [64]	validation's auc: 0.907658
# [65]	validation's auc: 0.908234
# [66]	validation's auc: 0.907343
# [67]	validation's auc: 0.907605
# [68]	validation's auc: 0.907186
# [69]	validation's auc: 0.907204
# [70]	validation's auc: 0.907082
# [71]	validation's auc: 0.90661
# [72]	validation's auc: 0.906977
# [73]	validation's auc: 0.907413
# [74]	validation's auc: 0.907797
# [75]	validation's auc: 0.908112
# [76]	validation's auc: 0.908234
# [77]	validation's auc: 0.90874
# [78]	validation's auc: 0.909194
# [79]	validation's auc: 0.909177
# [80]	validation's auc: 0.909281
# [81]	validation's auc: 0.908915
# [82]	validation's auc: 0.909159
# [83]	validation's auc: 0.908915
# [84]	validation's auc: 0.909177
# [85]	validation's auc: 0.90895
# [86]	validation's auc: 0.909107
# [87]	validation's auc: 0.909648
# [88]	validation's auc: 0.909945
# [89]	validation's auc: 0.910085
# [90]	validation's auc: 0.909945
# [91]	validation's auc: 0.910381
# [92]	validation's auc: 0.910521
# [93]	validation's auc: 0.910504
# [94]	validation's auc: 0.910277
# [95]	validation's auc: 0.909404
# [96]	validation's auc: 0.909054
# [97]	validation's auc: 0.90991
# [98]	validation's auc: 0.90874
# [99]	validation's auc: 0.908967
# [100]	validation's auc: 0.909054
# [101]	validation's auc: 0.909002
# [102]	validation's auc: 0.909159
# [103]	validation's auc: 0.909369
# [104]	validation's auc: 0.909526
# [105]	validation's auc: 0.909997
# [106]	validation's auc: 0.909194
# [107]	validation's auc: 0.909561
# [108]	validation's auc: 0.909316
# [109]	validation's auc: 0.910538
# [110]	validation's auc: 0.909858
# [111]	validation's auc: 0.910154
# [112]	validation's auc: 0.909543
# [113]	validation's auc: 0.910067
# [114]	validation's auc: 0.909456
# [115]	validation's auc: 0.909473
# [116]	validation's auc: 0.909927
# [117]	validation's auc: 0.909578
# [118]	validation's auc: 0.909683
# [119]	validation's auc: 0.909334
# [120]	validation's auc: 0.909107
# [121]	validation's auc: 0.908566
# [122]	validation's auc: 0.908391
# [123]	validation's auc: 0.908618
# [124]	validation's auc: 0.908932
# [125]	validation's auc: 0.909369
# [126]	validation's auc: 0.909229
# [127]	validation's auc: 0.90977
# [128]	validation's auc: 0.909753
# [129]	validation's auc: 0.91005
# [130]	validation's auc: 0.910224
# [131]	validation's auc: 0.910573
# [132]	validation's auc: 0.910137
# [133]	validation's auc: 0.910311
# [134]	validation's auc: 0.910207
# [135]	validation's auc: 0.910172
# [136]	validation's auc: 0.909578
# [137]	validation's auc: 0.909316
# [138]	validation's auc: 0.909212
# [139]	validation's auc: 0.909264
# [140]	validation's auc: 0.909456
# [141]	validation's auc: 0.909019
# [142]	validation's auc: 0.909299
# [143]	validation's auc: 0.908723
# [144]	validation's auc: 0.90895
# [145]	validation's auc: 0.909421
# [146]	validation's auc: 0.908897
# [147]	validation's auc: 0.908723
# [148]	validation's auc: 0.908461
# [149]	validation's auc: 0.908653
# [150]	validation's auc: 0.909054
# [151]	validation's auc: 0.908985
# [152]	validation's auc: 0.908426
# [153]	validation's auc: 0.908408
# [154]	validation's auc: 0.908339
# [155]	validation's auc: 0.908339
# [156]	validation's auc: 0.908531
# [157]	validation's auc: 0.9086
# [158]	validation's auc: 0.90874
# [159]	validation's auc: 0.908897
# [160]	validation's auc: 0.908426
# [161]	validation's auc: 0.908967
# [162]	validation's auc: 0.909212
# [163]	validation's auc: 0.908862
# [164]	validation's auc: 0.908705
# [165]	validation's auc: 0.908705
# [166]	validation's auc: 0.908304
# [167]	validation's auc: 0.908234
# [168]	validation's auc: 0.90867
# [169]	validation's auc: 0.90881
# [170]	validation's auc: 0.908373
# [171]	validation's auc: 0.908531
# [172]	validation's auc: 0.9086
# [173]	validation's auc: 0.90881
# [174]	validation's auc: 0.908286
# [175]	validation's auc: 0.908007
# [176]	validation's auc: 0.908199
# [177]	validation's auc: 0.908496
# [178]	validation's auc: 0.90881
# [179]	validation's auc: 0.909229
# [180]	validation's auc: 0.909246
# [181]	validation's auc: 0.909334
# Early stopping, best iteration is:
# [131]	validation's auc: 0.910573
# [1]	validation's auc: 0.777748
# Training until validation scores don't improve for 50 rounds
# [2]	validation's auc: 0.782758
# [3]	validation's auc: 0.796212
# [4]	validation's auc: 0.797874
# [5]	validation's auc: 0.806849
# [6]	validation's auc: 0.808218
# [7]	validation's auc: 0.80916
# [8]	validation's auc: 0.812872
# [9]	validation's auc: 0.811906
# [10]	validation's auc: 0.816703
# [11]	validation's auc: 0.818024
# [12]	validation's auc: 0.818642
# [13]	validation's auc: 0.816798
# [14]	validation's auc: 0.821499
# [15]	validation's auc: 0.824
# [16]	validation's auc: 0.823841
# [17]	validation's auc: 0.826944
# [18]	validation's auc: 0.827775
# [19]	validation's auc: 0.8306
# [20]	validation's auc: 0.832563
# [21]	validation's auc: 0.833339
# [22]	validation's auc: 0.833908
# [23]	validation's auc: 0.834874
# [24]	validation's auc: 0.837644
# [25]	validation's auc: 0.838974
# [26]	validation's auc: 0.838135
# [27]	validation's auc: 0.839749
# [28]	validation's auc: 0.84206
# [29]	validation's auc: 0.84339
# [30]	validation's auc: 0.844355
# [31]	validation's auc: 0.845147
# [32]	validation's auc: 0.84711
# [33]	validation's auc: 0.846746
# [34]	validation's auc: 0.847458
# [35]	validation's auc: 0.848772
# [36]	validation's auc: 0.849721
# [37]	validation's auc: 0.849943
# [38]	validation's auc: 0.848914
# [39]	validation's auc: 0.850687
# [40]	validation's auc: 0.851288
# [41]	validation's auc: 0.849579
# [42]	validation's auc: 0.849547
# [43]	validation's auc: 0.849357
# [44]	validation's auc: 0.84817
# [45]	validation's auc: 0.850054
# [46]	validation's auc: 0.851431
# [47]	validation's auc: 0.850133
# [48]	validation's auc: 0.849452
# [49]	validation's auc: 0.851067
# [50]	validation's auc: 0.8495
# [51]	validation's auc: 0.850497
# [52]	validation's auc: 0.850434
# [53]	validation's auc: 0.85075
# [54]	validation's auc: 0.851368
# [55]	validation's auc: 0.850244
# [56]	validation's auc: 0.850766
# [57]	validation's auc: 0.850228
# [58]	validation's auc: 0.850861
# [59]	validation's auc: 0.850355
# [60]	validation's auc: 0.849057
# [61]	validation's auc: 0.849136
# [62]	validation's auc: 0.849421
# [63]	validation's auc: 0.849579
# [64]	validation's auc: 0.849753
# [65]	validation's auc: 0.849247
# [66]	validation's auc: 0.851035
# [67]	validation's auc: 0.851447
# [68]	validation's auc: 0.852096
# [69]	validation's auc: 0.851953
# [70]	validation's auc: 0.851383
# [71]	validation's auc: 0.85151
# [72]	validation's auc: 0.851431
# [73]	validation's auc: 0.850972
# [74]	validation's auc: 0.850386
# [75]	validation's auc: 0.850481
# [76]	validation's auc: 0.850117
# [77]	validation's auc: 0.849658
# [78]	validation's auc: 0.84931
# [79]	validation's auc: 0.849405
# [80]	validation's auc: 0.849626
# [81]	validation's auc: 0.850038
# [82]	validation's auc: 0.849816
# [83]	validation's auc: 0.849484
# [84]	validation's auc: 0.84931
# [85]	validation's auc: 0.849547
# [86]	validation's auc: 0.850481
# [87]	validation's auc: 0.849674
# [88]	validation's auc: 0.850434
# [89]	validation's auc: 0.850909
# [90]	validation's auc: 0.850149
# [91]	validation's auc: 0.850149
# [92]	validation's auc: 0.849421
# [93]	validation's auc: 0.849516
# [94]	validation's auc: 0.849088
# [95]	validation's auc: 0.849832
# [96]	validation's auc: 0.849927
# [97]	validation's auc: 0.849959
# [98]	validation's auc: 0.850085
# [99]	validation's auc: 0.848914
# [100]	validation's auc: 0.848044
# [101]	validation's auc: 0.848249
# [102]	validation's auc: 0.84893
# [103]	validation's auc: 0.849864
# [104]	validation's auc: 0.850117
# [105]	validation's auc: 0.850861
# [106]	validation's auc: 0.851162
# [107]	validation's auc: 0.852175
# [108]	validation's auc: 0.851067
# [109]	validation's auc: 0.8517
# [110]	validation's auc: 0.852143
# [111]	validation's auc: 0.853346
# [112]	validation's auc: 0.853694
# [113]	validation's auc: 0.853869
# [114]	validation's auc: 0.854122
# [115]	validation's auc: 0.853789
# [116]	validation's auc: 0.85371
# [117]	validation's auc: 0.854359
# [118]	validation's auc: 0.853995
# [119]	validation's auc: 0.853014
# [120]	validation's auc: 0.853663
# [121]	validation's auc: 0.853599
# [122]	validation's auc: 0.854043
# [123]	validation's auc: 0.853457
# [124]	validation's auc: 0.853125
# [125]	validation's auc: 0.852776
# [126]	validation's auc: 0.85322
# [127]	validation's auc: 0.853346
# [128]	validation's auc: 0.853061
# [129]	validation's auc: 0.853299
# [130]	validation's auc: 0.853267
# [131]	validation's auc: 0.853884
# [132]	validation's auc: 0.853932
# [133]	validation's auc: 0.854644
# [134]	validation's auc: 0.854723
# [135]	validation's auc: 0.854613
# [136]	validation's auc: 0.855024
# [137]	validation's auc: 0.855072
# [138]	validation's auc: 0.855087
# [139]	validation's auc: 0.854723
# [140]	validation's auc: 0.854138
# [141]	validation's auc: 0.854027
# [142]	validation's auc: 0.854043
# [143]	validation's auc: 0.854217
# [144]	validation's auc: 0.853948
# [145]	validation's auc: 0.854454
# [146]	validation's auc: 0.854771
# [147]	validation's auc: 0.854676
# [148]	validation's auc: 0.854581
# [149]	validation's auc: 0.853884
# [150]	validation's auc: 0.853805
# [151]	validation's auc: 0.854011
# [152]	validation's auc: 0.854185
# [153]	validation's auc: 0.854185
# [154]	validation's auc: 0.854217
# [155]	validation's auc: 0.854961
# [156]	validation's auc: 0.854533
# [157]	validation's auc: 0.855056
# [158]	validation's auc: 0.854913
# [159]	validation's auc: 0.854866
# [160]	validation's auc: 0.855372
# [161]	validation's auc: 0.855546
# [162]	validation's auc: 0.855752
# [163]	validation's auc: 0.8558
# [164]	validation's auc: 0.854676
# [165]	validation's auc: 0.855135
# [166]	validation's auc: 0.855451
# [167]	validation's auc: 0.855024
# [168]	validation's auc: 0.85523
# [169]	validation's auc: 0.855167
# [170]	validation's auc: 0.855214
# [171]	validation's auc: 0.855388
# [172]	validation's auc: 0.855531
# [173]	validation's auc: 0.855404
# [174]	validation's auc: 0.855768
# [175]	validation's auc: 0.855483
# [176]	validation's auc: 0.855467
# [177]	validation's auc: 0.855356
# [178]	validation's auc: 0.855182
# [179]	validation's auc: 0.856164
# [180]	validation's auc: 0.856259
# [181]	validation's auc: 0.855815
# [182]	validation's auc: 0.856211
# [183]	validation's auc: 0.855673
# [184]	validation's auc: 0.855056
# [185]	validation's auc: 0.855198
# [186]	validation's auc: 0.855388
# [187]	validation's auc: 0.855499
# [188]	validation's auc: 0.855958
# [189]	validation's auc: 0.855784
# [190]	validation's auc: 0.855689
# [191]	validation's auc: 0.855974
# [192]	validation's auc: 0.856085
# [193]	validation's auc: 0.855974
# [194]	validation's auc: 0.85591
# [195]	validation's auc: 0.855847
# [196]	validation's auc: 0.855958
# [197]	validation's auc: 0.856449
# [198]	validation's auc: 0.856813
# [199]	validation's auc: 0.856829
# [200]	validation's auc: 0.856702
# [201]	validation's auc: 0.856559
# [202]	validation's auc: 0.856512
# [203]	validation's auc: 0.855879
# [204]	validation's auc: 0.856496
# [205]	validation's auc: 0.856085
# [206]	validation's auc: 0.85637
# [207]	validation's auc: 0.856275
# [208]	validation's auc: 0.856734
# [209]	validation's auc: 0.856528
# [210]	validation's auc: 0.856844
# [211]	validation's auc: 0.856449
# [212]	validation's auc: 0.857018
# [213]	validation's auc: 0.856797
# [214]	validation's auc: 0.85667
# [215]	validation's auc: 0.856639
# [216]	validation's auc: 0.856148
# [217]	validation's auc: 0.855689
# [218]	validation's auc: 0.85591
# [219]	validation's auc: 0.856148
# [220]	validation's auc: 0.856338
# [221]	validation's auc: 0.856322
# [222]	validation's auc: 0.856575
# [223]	validation's auc: 0.856544
# [224]	validation's auc: 0.856623
# [225]	validation's auc: 0.856876
# [226]	validation's auc: 0.856765
# [227]	validation's auc: 0.856892
# [228]	validation's auc: 0.856955
# [229]	validation's auc: 0.856892
# [230]	validation's auc: 0.857177
# [231]	validation's auc: 0.857066
# [232]	validation's auc: 0.857208
# [233]	validation's auc: 0.856955
# [234]	validation's auc: 0.856797
# [235]	validation's auc: 0.856607
# [236]	validation's auc: 0.856275
# [237]	validation's auc: 0.856037
# [238]	validation's auc: 0.855974
# [239]	validation's auc: 0.855752
# [240]	validation's auc: 0.856164
# [241]	validation's auc: 0.855531
# [242]	validation's auc: 0.855626
# [243]	validation's auc: 0.855879
# [244]	validation's auc: 0.855847
# [245]	validation's auc: 0.856005
# [246]	validation's auc: 0.856259
# [247]	validation's auc: 0.856417
# [248]	validation's auc: 0.856575
# [249]	validation's auc: 0.856449
# [250]	validation's auc: 0.856464
# [251]	validation's auc: 0.856575
# [252]	validation's auc: 0.856559
# [253]	validation's auc: 0.856306
# [254]	validation's auc: 0.855895
# [255]	validation's auc: 0.855705
# [256]	validation's auc: 0.855499
# [257]	validation's auc: 0.855436
# [258]	validation's auc: 0.855594
# [259]	validation's auc: 0.855657
# [260]	validation's auc: 0.855657
# [261]	validation's auc: 0.85599
# [262]	validation's auc: 0.856132
# [263]	validation's auc: 0.85667
# [264]	validation's auc: 0.856544
# [265]	validation's auc: 0.856797
# [266]	validation's auc: 0.857303
# [267]	validation's auc: 0.857383
# [268]	validation's auc: 0.857335
# [269]	validation's auc: 0.857129
# [270]	validation's auc: 0.857288
# [271]	validation's auc: 0.857145
# [272]	validation's auc: 0.857224
# [273]	validation's auc: 0.85743
# [274]	validation's auc: 0.857335
# [275]	validation's auc: 0.857398
# [276]	validation's auc: 0.857414
# [277]	validation's auc: 0.857826
# [278]	validation's auc: 0.858253
# [279]	validation's auc: 0.857921
# [280]	validation's auc: 0.857604
# [281]	validation's auc: 0.857303
# [282]	validation's auc: 0.857493
# [283]	validation's auc: 0.856876
# [284]	validation's auc: 0.857208
# [285]	validation's auc: 0.857462
# [286]	validation's auc: 0.857082
# [287]	validation's auc: 0.85724
# [288]	validation's auc: 0.857383
# [289]	validation's auc: 0.857509
# [290]	validation's auc: 0.857604
# [291]	validation's auc: 0.857636
# [292]	validation's auc: 0.857272
# [293]	validation's auc: 0.857588
# [294]	validation's auc: 0.857288
# [295]	validation's auc: 0.857414
# [296]	validation's auc: 0.857208
# [297]	validation's auc: 0.857778
# [298]	validation's auc: 0.857446
# [299]	validation's auc: 0.857319
# [300]	validation's auc: 0.857256
# [301]	validation's auc: 0.856813
# [302]	validation's auc: 0.856892
# [303]	validation's auc: 0.857145
# [304]	validation's auc: 0.857082
# [305]	validation's auc: 0.857604
# [306]	validation's auc: 0.857557
# [307]	validation's auc: 0.857557
# [308]	validation's auc: 0.858032
# [309]	validation's auc: 0.858047
# [310]	validation's auc: 0.857557
# [311]	validation's auc: 0.85762
# [312]	validation's auc: 0.857683
# [313]	validation's auc: 0.857478
# [314]	validation's auc: 0.857652
# [315]	validation's auc: 0.857398
# [316]	validation's auc: 0.858459
# [317]	validation's auc: 0.858475
# [318]	validation's auc: 0.858237
# [319]	validation's auc: 0.858285
# [320]	validation's auc: 0.858079
# [321]	validation's auc: 0.85819
# [322]	validation's auc: 0.858332
# [323]	validation's auc: 0.858142
# [324]	validation's auc: 0.858047
# [325]	validation's auc: 0.858221
# [326]	validation's auc: 0.858237
# [327]	validation's auc: 0.858253
# [328]	validation's auc: 0.857905
# [329]	validation's auc: 0.857335
# [330]	validation's auc: 0.857493
# [331]	validation's auc: 0.857335
# [332]	validation's auc: 0.857462
# [333]	validation's auc: 0.857525
# [334]	validation's auc: 0.85762
# [335]	validation's auc: 0.857398
# [336]	validation's auc: 0.85743
# [337]	validation's auc: 0.857478
# [338]	validation's auc: 0.857572
# [339]	validation's auc: 0.857478
# [340]	validation's auc: 0.857383
# [341]	validation's auc: 0.85724
# [342]	validation's auc: 0.857478
# [343]	validation's auc: 0.857414
# [344]	validation's auc: 0.857161
# [345]	validation's auc: 0.857335
# [346]	validation's auc: 0.857921
# [347]	validation's auc: 0.857905
# [348]	validation's auc: 0.857652
# [349]	validation's auc: 0.858301
# [350]	validation's auc: 0.858301
# [351]	validation's auc: 0.858459
# [352]	validation's auc: 0.858316
# [353]	validation's auc: 0.858237
# [354]	validation's auc: 0.858554
# [355]	validation's auc: 0.85857
# [356]	validation's auc: 0.858348
# [357]	validation's auc: 0.858997
# [358]	validation's auc: 0.858823
# [359]	validation's auc: 0.858459
# [360]	validation's auc: 0.858554
# [361]	validation's auc: 0.858206
# [362]	validation's auc: 0.858396
# [363]	validation's auc: 0.85838
# [364]	validation's auc: 0.858206
# [365]	validation's auc: 0.858696
# [366]	validation's auc: 0.858775
# [367]	validation's auc: 0.858918
# [368]	validation's auc: 0.858886
# [369]	validation's auc: 0.858981
# [370]	validation's auc: 0.859076
# [371]	validation's auc: 0.859599
# [372]	validation's auc: 0.859757
# [373]	validation's auc: 0.859757
# [374]	validation's auc: 0.859504
# [375]	validation's auc: 0.859409
# [376]	validation's auc: 0.859931
# [377]	validation's auc: 0.859884
# [378]	validation's auc: 0.859741
# [379]	validation's auc: 0.859773
# [380]	validation's auc: 0.859345
# [381]	validation's auc: 0.859488
# [382]	validation's auc: 0.859662
# [383]	validation's auc: 0.859947
# [384]	validation's auc: 0.860248
# [385]	validation's auc: 0.859884
# [386]	validation's auc: 0.860026
# [387]	validation's auc: 0.859915
# [388]	validation's auc: 0.859535
# [389]	validation's auc: 0.859393
# [390]	validation's auc: 0.859504
# [391]	validation's auc: 0.859409
# [392]	validation's auc: 0.859314
# [393]	validation's auc: 0.85906
# [394]	validation's auc: 0.85925
# [395]	validation's auc: 0.859424
# [396]	validation's auc: 0.859155
# [397]	validation's auc: 0.858791
# [398]	validation's auc: 0.859013
# [399]	validation's auc: 0.859551
# [400]	validation's auc: 0.859187
# [401]	validation's auc: 0.859013
# [402]	validation's auc: 0.859298
# [403]	validation's auc: 0.859472
# [404]	validation's auc: 0.859345
# [405]	validation's auc: 0.859314
# [406]	validation's auc: 0.859488
# [407]	validation's auc: 0.859725
# [408]	validation's auc: 0.859741
# [409]	validation's auc: 0.859551
# [410]	validation's auc: 0.85982
# [411]	validation's auc: 0.859804
# [412]	validation's auc: 0.859852
# [413]	validation's auc: 0.85982
# [414]	validation's auc: 0.860042
# [415]	validation's auc: 0.860184
# [416]	validation's auc: 0.860358
# [417]	validation's auc: 0.860073
# [418]	validation's auc: 0.859899
# [419]	validation's auc: 0.859741
# [420]	validation's auc: 0.859662
# [421]	validation's auc: 0.859282
# [422]	validation's auc: 0.859108
# [423]	validation's auc: 0.85906
# [424]	validation's auc: 0.85887
# [425]	validation's auc: 0.858934
# [426]	validation's auc: 0.859124
# [427]	validation's auc: 0.859108
# [428]	validation's auc: 0.858586
# [429]	validation's auc: 0.858696
# [430]	validation's auc: 0.858839
# [431]	validation's auc: 0.858886
# [432]	validation's auc: 0.859092
# [433]	validation's auc: 0.858823
# [434]	validation's auc: 0.859266
# [435]	validation's auc: 0.859393
# [436]	validation's auc: 0.859187
# [437]	validation's auc: 0.858902
# [438]	validation's auc: 0.859076
# [439]	validation's auc: 0.859155
# [440]	validation's auc: 0.859219
# [441]	validation's auc: 0.859298
# [442]	validation's auc: 0.859171
# [443]	validation's auc: 0.859504
# [444]	validation's auc: 0.859108
# [445]	validation's auc: 0.859298
# [446]	validation's auc: 0.859662
# [447]	validation's auc: 0.859567
# [448]	validation's auc: 0.859393
# [449]	validation's auc: 0.859393
# [450]	validation's auc: 0.859345
# [451]	validation's auc: 0.859393
# [452]	validation's auc: 0.859314
# [453]	validation's auc: 0.859393
# [454]	validation's auc: 0.859282
# [455]	validation's auc: 0.858981
# [456]	validation's auc: 0.858791
# [457]	validation's auc: 0.85876
# [458]	validation's auc: 0.859345
# [459]	validation's auc: 0.859424
# [460]	validation's auc: 0.859203
# [461]	validation's auc: 0.859694
# [462]	validation's auc: 0.85914
# [463]	validation's auc: 0.858965
# [464]	validation's auc: 0.859187
# [465]	validation's auc: 0.859108
# [466]	validation's auc: 0.859377
# Early stopping, best iteration is:
# [416]	validation's auc: 0.860358
# [1]	validation's auc: 0.849881
# Training until validation scores don't improve for 50 rounds
# [2]	validation's auc: 0.852225
# [3]	validation's auc: 0.858575
# [4]	validation's auc: 0.862275
# [5]	validation's auc: 0.865085
# [6]	validation's auc: 0.864592
# [7]	validation's auc: 0.869477
# [8]	validation's auc: 0.871722
# [9]	validation's auc: 0.875512
# [10]	validation's auc: 0.877676
# [11]	validation's auc: 0.878377
# [12]	validation's auc: 0.879751
# [13]	validation's auc: 0.881421
# [14]	validation's auc: 0.88196
# [15]	validation's auc: 0.882723
# [16]	validation's auc: 0.882202
# [17]	validation's auc: 0.883621
# [18]	validation's auc: 0.883909
# [19]	validation's auc: 0.884448
# [20]	validation's auc: 0.88575
# [21]	validation's auc: 0.883738
# [22]	validation's auc: 0.886145
# [23]	validation's auc: 0.88848
# [24]	validation's auc: 0.889414
# [25]	validation's auc: 0.88936
# [26]	validation's auc: 0.889989
# [27]	validation's auc: 0.891336
# [28]	validation's auc: 0.892108
# [29]	validation's auc: 0.891821
# [30]	validation's auc: 0.892359
# [31]	validation's auc: 0.892539
# [32]	validation's auc: 0.892323
# [33]	validation's auc: 0.892539
# [34]	validation's auc: 0.892826
# [35]	validation's auc: 0.894012
# [36]	validation's auc: 0.893617
# [37]	validation's auc: 0.893778
# [38]	validation's auc: 0.895251
# [39]	validation's auc: 0.894209
# [40]	validation's auc: 0.894138
# [41]	validation's auc: 0.893922
# [42]	validation's auc: 0.893491
# [43]	validation's auc: 0.893922
# [44]	validation's auc: 0.89376
# [45]	validation's auc: 0.894227
# [46]	validation's auc: 0.894497
# [47]	validation's auc: 0.894227
# [48]	validation's auc: 0.896365
# [49]	validation's auc: 0.896706
# [50]	validation's auc: 0.896508
# [51]	validation's auc: 0.897371
# [52]	validation's auc: 0.897371
# [53]	validation's auc: 0.898089
# [54]	validation's auc: 0.898502
# [55]	validation's auc: 0.89949
# [56]	validation's auc: 0.899041
# [57]	validation's auc: 0.899274
# [58]	validation's auc: 0.898574
# [59]	validation's auc: 0.898933
# [60]	validation's auc: 0.899634
# [61]	validation's auc: 0.899544
# [62]	validation's auc: 0.900999
# [63]	validation's auc: 0.900675
# [64]	validation's auc: 0.902004
# [65]	validation's auc: 0.902651
# [66]	validation's auc: 0.902274
# [67]	validation's auc: 0.902669
# [68]	validation's auc: 0.902992
# [69]	validation's auc: 0.902974
# [70]	validation's auc: 0.903352
# [71]	validation's auc: 0.903675
# [72]	validation's auc: 0.902867
# [73]	validation's auc: 0.90301
# [74]	validation's auc: 0.902615
# [75]	validation's auc: 0.903262
# [76]	validation's auc: 0.903226
# [77]	validation's auc: 0.903387
# [78]	validation's auc: 0.903226
# [79]	validation's auc: 0.903046
# [80]	validation's auc: 0.90425
# [81]	validation's auc: 0.904178
# [82]	validation's auc: 0.903603
# [83]	validation's auc: 0.904663
# [84]	validation's auc: 0.905004
# [85]	validation's auc: 0.905651
# [86]	validation's auc: 0.905992
# [87]	validation's auc: 0.906387
# [88]	validation's auc: 0.907213
# [89]	validation's auc: 0.906926
# [90]	validation's auc: 0.906459
# [91]	validation's auc: 0.906836
# [92]	validation's auc: 0.907052
# [93]	validation's auc: 0.907339
# [94]	validation's auc: 0.907267
# [95]	validation's auc: 0.907303
# [96]	validation's auc: 0.907034
# [97]	validation's auc: 0.907177
# [98]	validation's auc: 0.907716
# [99]	validation's auc: 0.907501
# [100]	validation's auc: 0.907195
# [101]	validation's auc: 0.907572
# [102]	validation's auc: 0.908363
# [103]	validation's auc: 0.907985
# [104]	validation's auc: 0.908399
# [105]	validation's auc: 0.908542
# [106]	validation's auc: 0.908219
# [107]	validation's auc: 0.908201
# [108]	validation's auc: 0.907968
# [109]	validation's auc: 0.907932
# [110]	validation's auc: 0.90856
# [111]	validation's auc: 0.908632
# [112]	validation's auc: 0.908417
# [113]	validation's auc: 0.908147
# [114]	validation's auc: 0.908093
# [115]	validation's auc: 0.908165
# [116]	validation's auc: 0.908165
# [117]	validation's auc: 0.908273
# [118]	validation's auc: 0.908668
# [119]	validation's auc: 0.908668
# [120]	validation's auc: 0.90856
# [121]	validation's auc: 0.907788
# [122]	validation's auc: 0.908021
# [123]	validation's auc: 0.908021
# [124]	validation's auc: 0.908363
# [125]	validation's auc: 0.908129
# [126]	validation's auc: 0.907932
# [127]	validation's auc: 0.907806
# [128]	validation's auc: 0.907644
# [129]	validation's auc: 0.907968
# [130]	validation's auc: 0.908075
# [131]	validation's auc: 0.907985
# [132]	validation's auc: 0.908201
# [133]	validation's auc: 0.90865
# [134]	validation's auc: 0.909153
# [135]	validation's auc: 0.909225
# [136]	validation's auc: 0.909333
# [137]	validation's auc: 0.909045
# [138]	validation's auc: 0.909171
# [139]	validation's auc: 0.908884
# [140]	validation's auc: 0.908937
# [141]	validation's auc: 0.909063
# [142]	validation's auc: 0.908884
# [143]	validation's auc: 0.909009
# [144]	validation's auc: 0.908919
# [145]	validation's auc: 0.908919
# [146]	validation's auc: 0.908704
# [147]	validation's auc: 0.908704
# [148]	validation's auc: 0.90856
# [149]	validation's auc: 0.909009
# [150]	validation's auc: 0.909333
# [151]	validation's auc: 0.909243
# [152]	validation's auc: 0.909548
# [153]	validation's auc: 0.90971
# [154]	validation's auc: 0.909566
# [155]	validation's auc: 0.909297
# [156]	validation's auc: 0.909925
# [157]	validation's auc: 0.909728
# [158]	validation's auc: 0.909476
# [159]	validation's auc: 0.909404
# [160]	validation's auc: 0.909422
# [161]	validation's auc: 0.909422
# [162]	validation's auc: 0.909548
# [163]	validation's auc: 0.909925
# [164]	validation's auc: 0.910069
# [165]	validation's auc: 0.909979
# [166]	validation's auc: 0.91041
# [167]	validation's auc: 0.910285
# [168]	validation's auc: 0.910374
# [169]	validation's auc: 0.910285
# [170]	validation's auc: 0.910123
# [171]	validation's auc: 0.910482
# [172]	validation's auc: 0.910841
# [173]	validation's auc: 0.910141
# [174]	validation's auc: 0.91068
# [175]	validation's auc: 0.910644
# [176]	validation's auc: 0.911039
# [177]	validation's auc: 0.910823
# [178]	validation's auc: 0.911111
# [179]	validation's auc: 0.911236
# [180]	validation's auc: 0.910518
# [181]	validation's auc: 0.910141
# [182]	validation's auc: 0.910159
# [183]	validation's auc: 0.910374
# [184]	validation's auc: 0.909997
# [185]	validation's auc: 0.909764
# [186]	validation's auc: 0.909746
# [187]	validation's auc: 0.909853
# [188]	validation's auc: 0.909925
# [189]	validation's auc: 0.910087
# [190]	validation's auc: 0.909979
# [191]	validation's auc: 0.910644
# [192]	validation's auc: 0.910626
# [193]	validation's auc: 0.910644
# [194]	validation's auc: 0.910428
# [195]	validation's auc: 0.910392
# [196]	validation's auc: 0.909871
# [197]	validation's auc: 0.909494
# [198]	validation's auc: 0.909512
# [199]	validation's auc: 0.909584
# [200]	validation's auc: 0.909943
# [201]	validation's auc: 0.909997
# [202]	validation's auc: 0.909818
# [203]	validation's auc: 0.910177
# [204]	validation's auc: 0.910518
# [205]	validation's auc: 0.910356
# [206]	validation's auc: 0.910698
# [207]	validation's auc: 0.910356
# [208]	validation's auc: 0.910518
# [209]	validation's auc: 0.910464
# [210]	validation's auc: 0.911075
# [211]	validation's auc: 0.910859
# [212]	validation's auc: 0.910751
# [213]	validation's auc: 0.91068
# [214]	validation's auc: 0.910895
# [215]	validation's auc: 0.910841
# [216]	validation's auc: 0.910662
# [217]	validation's auc: 0.910805
# [218]	validation's auc: 0.910859
# [219]	validation's auc: 0.910859
# [220]	validation's auc: 0.911003
# [221]	validation's auc: 0.910931
# [222]	validation's auc: 0.910913
# [223]	validation's auc: 0.911057
# [224]	validation's auc: 0.911254
# [225]	validation's auc: 0.910877
# [226]	validation's auc: 0.911039
# [227]	validation's auc: 0.910751
# [228]	validation's auc: 0.910626
# [229]	validation's auc: 0.91059
# [230]	validation's auc: 0.910823
# [231]	validation's auc: 0.910769
# [232]	validation's auc: 0.911003
# [233]	validation's auc: 0.910949
# [234]	validation's auc: 0.911308
# [235]	validation's auc: 0.911129
# [236]	validation's auc: 0.910716
# [237]	validation's auc: 0.910518
# [238]	validation's auc: 0.910751
# [239]	validation's auc: 0.910626
# [240]	validation's auc: 0.910644
# [241]	validation's auc: 0.910428
# [242]	validation's auc: 0.91068
# [243]	validation's auc: 0.910626
# [244]	validation's auc: 0.910051
# [245]	validation's auc: 0.910518
# [246]	validation's auc: 0.910392
# [247]	validation's auc: 0.910141
# [248]	validation's auc: 0.91032
# [249]	validation's auc: 0.910249
# [250]	validation's auc: 0.910356
# [251]	validation's auc: 0.910536
# [252]	validation's auc: 0.910769
# [253]	validation's auc: 0.910859
# [254]	validation's auc: 0.910895
# [255]	validation's auc: 0.910698
# [256]	validation's auc: 0.910338
# [257]	validation's auc: 0.910895
# [258]	validation's auc: 0.910805
# [259]	validation's auc: 0.911326
# [260]	validation's auc: 0.911236
# [261]	validation's auc: 0.911326
# [262]	validation's auc: 0.910949
# [263]	validation's auc: 0.910787
# [264]	validation's auc: 0.910716
# [265]	validation's auc: 0.910841
# [266]	validation's auc: 0.910734
# [267]	validation's auc: 0.910877
# [268]	validation's auc: 0.911057
# [269]	validation's auc: 0.910895
# [270]	validation's auc: 0.910913
# [271]	validation's auc: 0.911021
# [272]	validation's auc: 0.911183
# [273]	validation's auc: 0.910787
# [274]	validation's auc: 0.911039
# [275]	validation's auc: 0.910967
# [276]	validation's auc: 0.910716
# [277]	validation's auc: 0.910859
# [278]	validation's auc: 0.910985
# [279]	validation's auc: 0.910895
# [280]	validation's auc: 0.910985
# [281]	validation's auc: 0.911111
# [282]	validation's auc: 0.911111
# [283]	validation's auc: 0.911093
# [284]	validation's auc: 0.911039
# [285]	validation's auc: 0.910626
# [286]	validation's auc: 0.91068
# [287]	validation's auc: 0.910662
# [288]	validation's auc: 0.910751
# [289]	validation's auc: 0.910913
# [290]	validation's auc: 0.910446
# [291]	validation's auc: 0.910787
# [292]	validation's auc: 0.910608
# [293]	validation's auc: 0.910931
# [294]	validation's auc: 0.910877
# [295]	validation's auc: 0.910644
# [296]	validation's auc: 0.910716
# [297]	validation's auc: 0.911093
# [298]	validation's auc: 0.910913
# [299]	validation's auc: 0.910608
# [300]	validation's auc: 0.910626
# [301]	validation's auc: 0.910877
# [302]	validation's auc: 0.910913
# [303]	validation's auc: 0.910662
# [304]	validation's auc: 0.910554
# [305]	validation's auc: 0.910913
# [306]	validation's auc: 0.910608
# [307]	validation's auc: 0.911057
# [308]	validation's auc: 0.910949
# [309]	validation's auc: 0.910841
# Early stopping, best iteration is:
# [259]	validation's auc: 0.911326
# best roc_auc: 0.9113262447014873
# Accuracy: 97.38%
#               precision    recall  f1-score   support
#
#            0       0.98      0.98      0.98       786
#            1       0.96      0.96      0.96       360
#
#     accuracy                           0.97      1146
#    macro avg       0.97      0.97      0.97      1146
# weighted avg       0.97      0.97      0.97      1146
#
# ############################################################################
# ############################################################################
# year2020
#
# [1]	validation's auc: 0.848393
# Training until validation scores don't improve for 50 rounds
# [2]	validation's auc: 0.861011
# [3]	validation's auc: 0.861766
# [4]	validation's auc: 0.86572
# [5]	validation's auc: 0.86542
# [6]	validation's auc: 0.869095
# [7]	validation's auc: 0.878822
# [8]	validation's auc: 0.886385
# [9]	validation's auc: 0.887038
# [10]	validation's auc: 0.893156
# [11]	validation's auc: 0.894073
# [12]	validation's auc: 0.894975
# [13]	validation's auc: 0.897917
# [14]	validation's auc: 0.898592
# [15]	validation's auc: 0.900624
# [16]	validation's auc: 0.901034
# [17]	validation's auc: 0.900051
# [18]	validation's auc: 0.900433
# [19]	validation's auc: 0.901599
# [20]	validation's auc: 0.903382
# [21]	validation's auc: 0.903418
# [22]	validation's auc: 0.9038
# [23]	validation's auc: 0.904592
# [24]	validation's auc: 0.904401
# [25]	validation's auc: 0.904475
# [26]	validation's auc: 0.904548
# [27]	validation's auc: 0.904636
# [28]	validation's auc: 0.904548
# [29]	validation's auc: 0.903697
# [30]	validation's auc: 0.902964
# [31]	validation's auc: 0.903727
# [32]	validation's auc: 0.904592
# [33]	validation's auc: 0.904475
# [34]	validation's auc: 0.905604
# [35]	validation's auc: 0.906133
# [36]	validation's auc: 0.905223
# [37]	validation's auc: 0.905106
# [38]	validation's auc: 0.90468
# [39]	validation's auc: 0.903932
# [40]	validation's auc: 0.903404
# [41]	validation's auc: 0.903668
# [42]	validation's auc: 0.903888
# [43]	validation's auc: 0.904005
# [44]	validation's auc: 0.90336
# [45]	validation's auc: 0.903888
# [46]	validation's auc: 0.904343
# [47]	validation's auc: 0.904886
# [48]	validation's auc: 0.904269
# [49]	validation's auc: 0.903727
# [50]	validation's auc: 0.903917
# [51]	validation's auc: 0.90355
# [52]	validation's auc: 0.903624
# [53]	validation's auc: 0.904064
# [54]	validation's auc: 0.903712
# [55]	validation's auc: 0.903638
# [56]	validation's auc: 0.904343
# [57]	validation's auc: 0.904445
# [58]	validation's auc: 0.904548
# [59]	validation's auc: 0.904079
# [60]	validation's auc: 0.903741
# [61]	validation's auc: 0.903991
# [62]	validation's auc: 0.905135
# [63]	validation's auc: 0.904445
# [64]	validation's auc: 0.905164
# [65]	validation's auc: 0.904445
# [66]	validation's auc: 0.903565
# [67]	validation's auc: 0.904167
# [68]	validation's auc: 0.904005
# [69]	validation's auc: 0.903433
# [70]	validation's auc: 0.903844
# [71]	validation's auc: 0.904269
# [72]	validation's auc: 0.90355
# [73]	validation's auc: 0.9038
# [74]	validation's auc: 0.904812
# [75]	validation's auc: 0.904533
# [76]	validation's auc: 0.904445
# [77]	validation's auc: 0.903844
# [78]	validation's auc: 0.903066
# [79]	validation's auc: 0.903022
# [80]	validation's auc: 0.903785
# [81]	validation's auc: 0.903771
# [82]	validation's auc: 0.903374
# [83]	validation's auc: 0.903536
# [84]	validation's auc: 0.903565
# [85]	validation's auc: 0.903712
# Early stopping, best iteration is:
# [35]	validation's auc: 0.906133
# [1]	validation's auc: 0.847198
# Training until validation scores don't improve for 50 rounds
# [2]	validation's auc: 0.851064
# [3]	validation's auc: 0.860293
# [4]	validation's auc: 0.859566
# [5]	validation's auc: 0.862906
# [6]	validation's auc: 0.868047
# [7]	validation's auc: 0.871334
# [8]	validation's auc: 0.873567
# [9]	validation's auc: 0.877023
# [10]	validation's auc: 0.878666
# [11]	validation's auc: 0.883397
# [12]	validation's auc: 0.886684
# [13]	validation's auc: 0.888443
# [14]	validation's auc: 0.89094
# [15]	validation's auc: 0.890813
# [16]	validation's auc: 0.893279
# [17]	validation's auc: 0.890982
# [18]	validation's auc: 0.893468
# [19]	validation's auc: 0.896376
# [20]	validation's auc: 0.897767
# [21]	validation's auc: 0.897809
# [22]	validation's auc: 0.899579
# [23]	validation's auc: 0.900716
# [24]	validation's auc: 0.901096
# [25]	validation's auc: 0.900253
# [26]	validation's auc: 0.899874
# [27]	validation's auc: 0.898757
# [28]	validation's auc: 0.89941
# [29]	validation's auc: 0.898483
# [30]	validation's auc: 0.898104
# [31]	validation's auc: 0.897745
# [32]	validation's auc: 0.898904
# [33]	validation's auc: 0.898862
# [34]	validation's auc: 0.899726
# [35]	validation's auc: 0.898609
# [36]	validation's auc: 0.897956
# [37]	validation's auc: 0.899241
# [38]	validation's auc: 0.899473
# [39]	validation's auc: 0.898989
# [40]	validation's auc: 0.898883
# [41]	validation's auc: 0.899768
# [42]	validation's auc: 0.899874
# [43]	validation's auc: 0.90019
# [44]	validation's auc: 0.90019
# [45]	validation's auc: 0.899789
# [46]	validation's auc: 0.900063
# [47]	validation's auc: 0.899368
# [48]	validation's auc: 0.899621
# [49]	validation's auc: 0.899494
# [50]	validation's auc: 0.899705
# [51]	validation's auc: 0.900801
# [52]	validation's auc: 0.901222
# [53]	validation's auc: 0.900885
# [54]	validation's auc: 0.902507
# [55]	validation's auc: 0.90217
# [56]	validation's auc: 0.900759
# [57]	validation's auc: 0.901812
# [58]	validation's auc: 0.901454
# [59]	validation's auc: 0.900358
# [60]	validation's auc: 0.900885
# [61]	validation's auc: 0.901117
# [62]	validation's auc: 0.902339
# [63]	validation's auc: 0.903182
# [64]	validation's auc: 0.90394
# [65]	validation's auc: 0.903076
# [66]	validation's auc: 0.901875
# [67]	validation's auc: 0.901496
# [68]	validation's auc: 0.901643
# [69]	validation's auc: 0.901412
# [70]	validation's auc: 0.901243
# [71]	validation's auc: 0.901559
# [72]	validation's auc: 0.902339
# [73]	validation's auc: 0.902613
# [74]	validation's auc: 0.903118
# [75]	validation's auc: 0.903477
# [76]	validation's auc: 0.902676
# [77]	validation's auc: 0.90276
# [78]	validation's auc: 0.90177
# [79]	validation's auc: 0.902297
# [80]	validation's auc: 0.901665
# [81]	validation's auc: 0.901643
# [82]	validation's auc: 0.901096
# [83]	validation's auc: 0.901475
# [84]	validation's auc: 0.902465
# [85]	validation's auc: 0.903224
# [86]	validation's auc: 0.903161
# [87]	validation's auc: 0.903456
# [88]	validation's auc: 0.903687
# [89]	validation's auc: 0.903371
# [90]	validation's auc: 0.903413
# [91]	validation's auc: 0.902718
# [92]	validation's auc: 0.903013
# [93]	validation's auc: 0.903097
# [94]	validation's auc: 0.902718
# [95]	validation's auc: 0.901917
# [96]	validation's auc: 0.903097
# [97]	validation's auc: 0.903708
# [98]	validation's auc: 0.903624
# [99]	validation's auc: 0.903076
# [100]	validation's auc: 0.903224
# [101]	validation's auc: 0.902866
# [102]	validation's auc: 0.903413
# [103]	validation's auc: 0.902908
# [104]	validation's auc: 0.902634
# [105]	validation's auc: 0.903287
# [106]	validation's auc: 0.903287
# [107]	validation's auc: 0.902528
# [108]	validation's auc: 0.902781
# [109]	validation's auc: 0.902297
# [110]	validation's auc: 0.902002
# [111]	validation's auc: 0.901917
# [112]	validation's auc: 0.901643
# [113]	validation's auc: 0.901391
# [114]	validation's auc: 0.901159
# Early stopping, best iteration is:
# [64]	validation's auc: 0.90394
# [1]	validation's auc: 0.794458
# Training until validation scores don't improve for 50 rounds
# [2]	validation's auc: 0.805989
# [3]	validation's auc: 0.805895
# [4]	validation's auc: 0.806204
# [5]	validation's auc: 0.804549
# [6]	validation's auc: 0.808617
# [7]	validation's auc: 0.811516
# [8]	validation's auc: 0.812058
# [9]	validation's auc: 0.81448
# [10]	validation's auc: 0.814789
# [11]	validation's auc: 0.8178
# [12]	validation's auc: 0.817164
# [13]	validation's auc: 0.821803
# [14]	validation's auc: 0.823318
# [15]	validation's auc: 0.824992
# [16]	validation's auc: 0.828676
# [17]	validation's auc: 0.831444
# [18]	validation's auc: 0.833408
# [19]	validation's auc: 0.835447
# [20]	validation's auc: 0.836214
# [21]	validation's auc: 0.837158
# [22]	validation's auc: 0.836803
# [23]	validation's auc: 0.83583
# [24]	validation's auc: 0.836672
# [25]	validation's auc: 0.837196
# [26]	validation's auc: 0.837551
# [27]	validation's auc: 0.839103
# [28]	validation's auc: 0.838542
# [29]	validation's auc: 0.837757
# [30]	validation's auc: 0.838206
# [31]	validation's auc: 0.839178
# [32]	validation's auc: 0.838589
# [33]	validation's auc: 0.838065
# [34]	validation's auc: 0.837654
# [35]	validation's auc: 0.83872
# [36]	validation's auc: 0.838963
# [37]	validation's auc: 0.838065
# [38]	validation's auc: 0.838439
# [39]	validation's auc: 0.837411
# [40]	validation's auc: 0.836756
# [41]	validation's auc: 0.836401
# [42]	validation's auc: 0.835335
# [43]	validation's auc: 0.834998
# [44]	validation's auc: 0.835091
# [45]	validation's auc: 0.836307
# [46]	validation's auc: 0.835073
# [47]	validation's auc: 0.835709
# [48]	validation's auc: 0.836195
# [49]	validation's auc: 0.835709
# [50]	validation's auc: 0.83627
# [51]	validation's auc: 0.836158
# [52]	validation's auc: 0.836775
# [53]	validation's auc: 0.837373
# [54]	validation's auc: 0.837298
# [55]	validation's auc: 0.837841
# [56]	validation's auc: 0.839019
# [57]	validation's auc: 0.839431
# [58]	validation's auc: 0.84059
# [59]	validation's auc: 0.83988
# [60]	validation's auc: 0.839693
# [61]	validation's auc: 0.839767
# [62]	validation's auc: 0.841189
# [63]	validation's auc: 0.841058
# [64]	validation's auc: 0.841638
# [65]	validation's auc: 0.841376
# [66]	validation's auc: 0.841282
# [67]	validation's auc: 0.841039
# [68]	validation's auc: 0.840553
# [69]	validation's auc: 0.840403
# [70]	validation's auc: 0.840777
# [71]	validation's auc: 0.839693
# [72]	validation's auc: 0.839057
# [73]	validation's auc: 0.83973
# [74]	validation's auc: 0.838159
# [75]	validation's auc: 0.837747
# [76]	validation's auc: 0.837897
# [77]	validation's auc: 0.837186
# [78]	validation's auc: 0.837953
# [79]	validation's auc: 0.838271
# [80]	validation's auc: 0.83786
# [81]	validation's auc: 0.838065
# [82]	validation's auc: 0.837691
# [83]	validation's auc: 0.836756
# [84]	validation's auc: 0.837654
# [85]	validation's auc: 0.838009
# [86]	validation's auc: 0.838234
# [87]	validation's auc: 0.838402
# [88]	validation's auc: 0.838944
# [89]	validation's auc: 0.838626
# [90]	validation's auc: 0.839057
# [91]	validation's auc: 0.840104
# [92]	validation's auc: 0.83973
# [93]	validation's auc: 0.840441
# [94]	validation's auc: 0.840366
# [95]	validation's auc: 0.840403
# [96]	validation's auc: 0.840104
# [97]	validation's auc: 0.83988
# [98]	validation's auc: 0.840272
# [99]	validation's auc: 0.839992
# [100]	validation's auc: 0.839618
# [101]	validation's auc: 0.838907
# [102]	validation's auc: 0.838982
# [103]	validation's auc: 0.838626
# [104]	validation's auc: 0.840048
# [105]	validation's auc: 0.840665
# [106]	validation's auc: 0.840441
# [107]	validation's auc: 0.839861
# [108]	validation's auc: 0.83915
# [109]	validation's auc: 0.839487
# [110]	validation's auc: 0.839244
# [111]	validation's auc: 0.8393
# [112]	validation's auc: 0.839917
# [113]	validation's auc: 0.840104
# [114]	validation's auc: 0.840441
# Early stopping, best iteration is:
# [64]	validation's auc: 0.841638
# [1]	validation's auc: 0.816329
# Training until validation scores don't improve for 50 rounds
# [2]	validation's auc: 0.819302
# [3]	validation's auc: 0.822813
# [4]	validation's auc: 0.834199
# [5]	validation's auc: 0.84539
# [6]	validation's auc: 0.846812
# [7]	validation's auc: 0.848632
# [8]	validation's auc: 0.851648
# [9]	validation's auc: 0.853081
# [10]	validation's auc: 0.855666
# [11]	validation's auc: 0.857411
# [12]	validation's auc: 0.859037
# [13]	validation's auc: 0.862538
# [14]	validation's auc: 0.86243
# [15]	validation's auc: 0.862936
# [16]	validation's auc: 0.866372
# [17]	validation's auc: 0.866523
# [18]	validation's auc: 0.868354
# [19]	validation's auc: 0.86816
# [20]	validation's auc: 0.868979
# [21]	validation's auc: 0.870379
# [22]	validation's auc: 0.872964
# [23]	validation's auc: 0.873201
# [24]	validation's auc: 0.873847
# [25]	validation's auc: 0.874343
# [26]	validation's auc: 0.875442
# [27]	validation's auc: 0.876691
# [28]	validation's auc: 0.877273
# [29]	validation's auc: 0.879427
# [30]	validation's auc: 0.880547
# [31]	validation's auc: 0.880784
# [32]	validation's auc: 0.88212
# [33]	validation's auc: 0.882249
# [34]	validation's auc: 0.882809
# [35]	validation's auc: 0.883283
# [36]	validation's auc: 0.882788
# [37]	validation's auc: 0.883326
# [38]	validation's auc: 0.883348
# [39]	validation's auc: 0.88296
# [40]	validation's auc: 0.883865
# [41]	validation's auc: 0.883865
# [42]	validation's auc: 0.881947
# [43]	validation's auc: 0.881689
# [44]	validation's auc: 0.881991
# [45]	validation's auc: 0.881323
# [46]	validation's auc: 0.880827
# [47]	validation's auc: 0.881237
# [48]	validation's auc: 0.881215
# [49]	validation's auc: 0.882206
# [50]	validation's auc: 0.881452
# [51]	validation's auc: 0.88031
# [52]	validation's auc: 0.881366
# [53]	validation's auc: 0.881926
# [54]	validation's auc: 0.882012
# [55]	validation's auc: 0.881969
# [56]	validation's auc: 0.880956
# [57]	validation's auc: 0.880289
# [58]	validation's auc: 0.880246
# [59]	validation's auc: 0.880181
# [60]	validation's auc: 0.879664
# [61]	validation's auc: 0.880461
# [62]	validation's auc: 0.879168
# [63]	validation's auc: 0.878931
# [64]	validation's auc: 0.878371
# [65]	validation's auc: 0.877984
# [66]	validation's auc: 0.878565
# [67]	validation's auc: 0.87779
# [68]	validation's auc: 0.877402
# [69]	validation's auc: 0.87766
# [70]	validation's auc: 0.877984
# [71]	validation's auc: 0.878802
# [72]	validation's auc: 0.879685
# [73]	validation's auc: 0.878824
# [74]	validation's auc: 0.879233
# [75]	validation's auc: 0.879879
# [76]	validation's auc: 0.87975
# [77]	validation's auc: 0.880181
# [78]	validation's auc: 0.880073
# [79]	validation's auc: 0.880267
# [80]	validation's auc: 0.881172
# [81]	validation's auc: 0.880892
# [82]	validation's auc: 0.881689
# [83]	validation's auc: 0.881495
# [84]	validation's auc: 0.881
# ...
# [24]	validation's auc: 0.874152
# [25]	validation's auc: 0.874926
# [26]	validation's auc: 0.874648
# [27]	validation's auc: 0.87347
# [28]	validation's auc: 0.873842
# [29]	validation's auc: 0.875298
# [30]	validation's auc: 0.876228
# [31]	validation's auc: 0.877498
# [32]	validation's auc: 0.878241
# [33]	validation's auc: 0.87914
# [34]	validation's auc: 0.880658
# [35]	validation's auc: 0.880286
# [36]	validation's auc: 0.879884
# [37]	validation's auc: 0.878737
# [38]	validation's auc: 0.880441
# [39]	validation's auc: 0.882114
# [40]	validation's auc: 0.880534
# [41]	validation's auc: 0.879295
# [42]	validation's auc: 0.880937
# [43]	validation's auc: 0.882858
# [44]	validation's auc: 0.884407
# [45]	validation's auc: 0.883818
# [46]	validation's auc: 0.884748
# [47]	validation's auc: 0.884593
# [48]	validation's auc: 0.884469
# [49]	validation's auc: 0.883663
# [50]	validation's auc: 0.884345
# [51]	validation's auc: 0.886111
# [52]	validation's auc: 0.885925
# [53]	validation's auc: 0.886049
# [54]	validation's auc: 0.885429
# [55]	validation's auc: 0.884159
# [56]	validation's auc: 0.884035
# [57]	validation's auc: 0.884686
# [58]	validation's auc: 0.88577
# [59]	validation's auc: 0.885305
# [60]	validation's auc: 0.886483
# [61]	validation's auc: 0.886638
# [62]	validation's auc: 0.885801
# [63]	validation's auc: 0.885398
# [64]	validation's auc: 0.885274
# [65]	validation's auc: 0.884407
# [66]	validation's auc: 0.88515
# [67]	validation's auc: 0.885615
# [68]	validation's auc: 0.884004
# [69]	validation's auc: 0.883973
# [70]	validation's auc: 0.883292
# [71]	validation's auc: 0.882765
# [72]	validation's auc: 0.8823
# [73]	validation's auc: 0.88261
# [74]	validation's auc: 0.883261
# [75]	validation's auc: 0.883446
# [76]	validation's auc: 0.883694
# [77]	validation's auc: 0.884221
# [78]	validation's auc: 0.883601
# [79]	validation's auc: 0.882889
# [80]	validation's auc: 0.88134
# [81]	validation's auc: 0.882331
# [82]	validation's auc: 0.882641
# [83]	validation's auc: 0.881897
# [84]	validation's auc: 0.882114
# [85]	validation's auc: 0.881835
# [86]	validation's auc: 0.881588
# [87]	validation's auc: 0.882548
# [88]	validation's auc: 0.882734
# [89]	validation's auc: 0.882238
# [90]	validation's auc: 0.882269
# [91]	validation's auc: 0.881123
# [92]	validation's auc: 0.880441
# [93]	validation's auc: 0.880255
# [94]	validation's auc: 0.880968
# [95]	validation's auc: 0.880937
# [96]	validation's auc: 0.881092
# [97]	validation's auc: 0.880379
# [98]	validation's auc: 0.880255
# [99]	validation's auc: 0.881061
# [100]	validation's auc: 0.880906
# [101]	validation's auc: 0.880906
# [102]	validation's auc: 0.881247
# [103]	validation's auc: 0.882579
# [104]	validation's auc: 0.880658
# [105]	validation's auc: 0.8801
# [106]	validation's auc: 0.880782
# [107]	validation's auc: 0.881278
# [108]	validation's auc: 0.880596
# [109]	validation's auc: 0.879976
# [110]	validation's auc: 0.881866
# [111]	validation's auc: 0.882083
# Early stopping, best iteration is:
# [61]	validation's auc: 0.886638
# [1]	validation's auc: 0.779393
# Training until validation scores don't improve for 50 rounds
# [2]	validation's auc: 0.789056
# [3]	validation's auc: 0.815746
# [4]	validation's auc: 0.818663
# [5]	validation's auc: 0.825438
# [6]	validation's auc: 0.829887
# [7]	validation's auc: 0.827088
# [8]	validation's auc: 0.828178
# [9]	validation's auc: 0.833215
# [10]	validation's auc: 0.831404
# [11]	validation's auc: 0.834409
# [12]	validation's auc: 0.83432
# [13]	validation's auc: 0.836677
# [14]	validation's auc: 0.836618
# [15]	validation's auc: 0.837855
# [16]	validation's auc: 0.836883
# [17]	validation's auc: 0.836206
# [18]	validation's auc: 0.835793
# [19]	validation's auc: 0.835528
# [20]	validation's auc: 0.834998
# [21]	validation's auc: 0.836559
# [22]	validation's auc: 0.832199
# [23]	validation's auc: 0.832847
# [24]	validation's auc: 0.833289
# [25]	validation's auc: 0.834526
# [26]	validation's auc: 0.835587
# [27]	validation's auc: 0.835705
# [28]	validation's auc: 0.83432
# [29]	validation's auc: 0.835175
# [30]	validation's auc: 0.833878
# [31]	validation's auc: 0.834438
# [32]	validation's auc: 0.834379
# [33]	validation's auc: 0.834909
# [34]	validation's auc: 0.836412
# [35]	validation's auc: 0.835675
# [36]	validation's auc: 0.835823
# [37]	validation's auc: 0.835292
# [38]	validation's auc: 0.836471
# [39]	validation's auc: 0.835204
# [40]	validation's auc: 0.835882
# [41]	validation's auc: 0.83541
# [42]	validation's auc: 0.837472
# [43]	validation's auc: 0.838062
# [44]	validation's auc: 0.839417
# [45]	validation's auc: 0.838533
# [46]	validation's auc: 0.839652
# [47]	validation's auc: 0.839888
# [48]	validation's auc: 0.839387
# [49]	validation's auc: 0.839593
# [50]	validation's auc: 0.837738
# [51]	validation's auc: 0.838297
# [52]	validation's auc: 0.838386
# [53]	validation's auc: 0.838474
# [54]	validation's auc: 0.837679
# [55]	validation's auc: 0.83653
# [56]	validation's auc: 0.838945
# [57]	validation's auc: 0.839034
# [58]	validation's auc: 0.839682
# [59]	validation's auc: 0.840153
# [60]	validation's auc: 0.839711
# [61]	validation's auc: 0.840625
# [62]	validation's auc: 0.840035
# [63]	validation's auc: 0.840654
# [64]	validation's auc: 0.841243
# [65]	validation's auc: 0.840595
# [66]	validation's auc: 0.841125
# [67]	validation's auc: 0.841626
# [68]	validation's auc: 0.841273
# [69]	validation's auc: 0.841273
# [70]	validation's auc: 0.840595
# [71]	validation's auc: 0.841626
# [72]	validation's auc: 0.840831
# [73]	validation's auc: 0.840536
# [74]	validation's auc: 0.841302
# [75]	validation's auc: 0.83977
# [76]	validation's auc: 0.840772
# [77]	validation's auc: 0.840654
# [78]	validation's auc: 0.841008
# [79]	validation's auc: 0.840831
# [80]	validation's auc: 0.840389
# [81]	validation's auc: 0.841125
# [82]	validation's auc: 0.842952
# [83]	validation's auc: 0.84416
# [84]	validation's auc: 0.843423
# [85]	validation's auc: 0.8436
# [86]	validation's auc: 0.844602
# [87]	validation's auc: 0.844543
# [88]	validation's auc: 0.843423
# [89]	validation's auc: 0.843217
# [90]	validation's auc: 0.843276
# [91]	validation's auc: 0.842628
# [92]	validation's auc: 0.843394
# [93]	validation's auc: 0.843453
# [94]	validation's auc: 0.843453
# [95]	validation's auc: 0.843423
# [96]	validation's auc: 0.843836
# [97]	validation's auc: 0.843011
# [98]	validation's auc: 0.842922
# [99]	validation's auc: 0.842363
# [100]	validation's auc: 0.844336
# [101]	validation's auc: 0.843188
# [102]	validation's auc: 0.842952
# [103]	validation's auc: 0.844366
# [104]	validation's auc: 0.843777
# [105]	validation's auc: 0.843423
# [106]	validation's auc: 0.844278
# [107]	validation's auc: 0.843688
# [108]	validation's auc: 0.843512
# [109]	validation's auc: 0.842805
# [110]	validation's auc: 0.842598
# [111]	validation's auc: 0.842156
# [112]	validation's auc: 0.843246
# [113]	validation's auc: 0.84357
# [114]	validation's auc: 0.84413
# [115]	validation's auc: 0.843305
# [116]	validation's auc: 0.842893
# [117]	validation's auc: 0.843512
# [118]	validation's auc: 0.844896
# [119]	validation's auc: 0.846016
# [120]	validation's auc: 0.845986
# [121]	validation's auc: 0.845338
# [122]	validation's auc: 0.844631
# [123]	validation's auc: 0.844012
# [124]	validation's auc: 0.844101
# [125]	validation's auc: 0.843217
# [126]	validation's auc: 0.844366
# [127]	validation's auc: 0.843541
# [128]	validation's auc: 0.843983
# [129]	validation's auc: 0.843806
# [130]	validation's auc: 0.843659
# [131]	validation's auc: 0.843747
# [132]	validation's auc: 0.843217
# [133]	validation's auc: 0.843924
# [134]	validation's auc: 0.844278
# [135]	validation's auc: 0.844395
# [136]	validation's auc: 0.843865
# [137]	validation's auc: 0.843924
# [138]	validation's auc: 0.843806
# [139]	validation's auc: 0.843305
# [140]	validation's auc: 0.84357
# [141]	validation's auc: 0.844336
# [142]	validation's auc: 0.842922
# [143]	validation's auc: 0.84304
# [144]	validation's auc: 0.842098
# [145]	validation's auc: 0.841008
# [146]	validation's auc: 0.842422
# [147]	validation's auc: 0.842304
# [148]	validation's auc: 0.842245
# [149]	validation's auc: 0.842127
# [150]	validation's auc: 0.841361
# [151]	validation's auc: 0.843099
# [152]	validation's auc: 0.84248
# [153]	validation's auc: 0.842304
# [154]	validation's auc: 0.84248
# [155]	validation's auc: 0.841567
# [156]	validation's auc: 0.841715
# [157]	validation's auc: 0.840949
# [158]	validation's auc: 0.840772
# [159]	validation's auc: 0.840448
# [160]	validation's auc: 0.840094
# [161]	validation's auc: 0.840919
# [162]	validation's auc: 0.841538
# [163]	validation's auc: 0.840212
# [164]	validation's auc: 0.840978
# [165]	validation's auc: 0.841685
# [166]	validation's auc: 0.841626
# [167]	validation's auc: 0.841773
# [168]	validation's auc: 0.840801
# [169]	validation's auc: 0.841656
# Early stopping, best iteration is:
# [119]	validation's auc: 0.846016
# [1]	validation's auc: 0.839167
# Training until validation scores don't improve for 50 rounds
# [2]	validation's auc: 0.852827
# [3]	validation's auc: 0.854213
# [4]	validation's auc: 0.858572
# [5]	validation's auc: 0.863164
# [6]	validation's auc: 0.863598
# [7]	validation's auc: 0.870512
# [8]	validation's auc: 0.869143
# [9]	validation's auc: 0.872599
# [10]	validation's auc: 0.879012
# [11]	validation's auc: 0.881801
# [12]	validation's auc: 0.883671
# [13]	validation's auc: 0.883087
# [14]	validation's auc: 0.883404
# [15]	validation's auc: 0.884289
# [16]	validation's auc: 0.887145
# [17]	validation's auc: 0.888481
# [18]	validation's auc: 0.892088
# [19]	validation's auc: 0.893691
# [20]	validation's auc: 0.891086
# [21]	validation's auc: 0.890819
# [22]	validation's auc: 0.892756
# [23]	validation's auc: 0.895962
# [24]	validation's auc: 0.893491
# [25]	validation's auc: 0.89339
# [26]	validation's auc: 0.893257
# [27]	validation's auc: 0.894392
# [28]	validation's auc: 0.895461
# [29]	validation's auc: 0.896663
# [30]	validation's auc: 0.896764
# [31]	validation's auc: 0.895461
# [32]	validation's auc: 0.897465
# [33]	validation's auc: 0.897498
# [34]	validation's auc: 0.896931
# [35]	validation's auc: 0.894793
# [36]	validation's auc: 0.895895
# [37]	validation's auc: 0.896864
# [38]	validation's auc: 0.897866
# [39]	validation's auc: 0.899536
# [40]	validation's auc: 0.900605
# [41]	validation's auc: 0.901106
# [42]	validation's auc: 0.901373
# [43]	validation's auc: 0.90174
# [44]	validation's auc: 0.902608
# [45]	validation's auc: 0.902475
# [46]	validation's auc: 0.902675
# [47]	validation's auc: 0.902976
# [48]	validation's auc: 0.903677
# [49]	validation's auc: 0.903711
# [50]	validation's auc: 0.903143
# [51]	validation's auc: 0.903243
# [52]	validation's auc: 0.903043
# [53]	validation's auc: 0.902675
# [54]	validation's auc: 0.90331
# [55]	validation's auc: 0.904345
# [56]	validation's auc: 0.904345
# [57]	validation's auc: 0.903978
# [58]	validation's auc: 0.90488
# [59]	validation's auc: 0.904512
# [60]	validation's auc: 0.903109
# [61]	validation's auc: 0.904045
# [62]	validation's auc: 0.904946
# [63]	validation's auc: 0.905147
# [64]	validation's auc: 0.90508
# [65]	validation's auc: 0.906383
# [66]	validation's auc: 0.906383
# [67]	validation's auc: 0.907652
# [68]	validation's auc: 0.907251
# [69]	validation's auc: 0.909088
# [70]	validation's auc: 0.908787
# [71]	validation's auc: 0.908587
# [72]	validation's auc: 0.909388
# [73]	validation's auc: 0.909889
# [74]	validation's auc: 0.909656
# [75]	validation's auc: 0.909188
# [76]	validation's auc: 0.908353
# [77]	validation's auc: 0.907752
# [78]	validation's auc: 0.907084
# [79]	validation's auc: 0.90862
# [80]	validation's auc: 0.908353
# [81]	validation's auc: 0.907151
# [82]	validation's auc: 0.907051
# [83]	validation's auc: 0.907819
# [84]	validation's auc: 0.907084
# [85]	validation's auc: 0.907886
# [86]	validation's auc: 0.907819
# [87]	validation's auc: 0.908988
# [88]	validation's auc: 0.909288
# [89]	validation's auc: 0.908353
# [90]	validation's auc: 0.908119
# [91]	validation's auc: 0.907886
# [92]	validation's auc: 0.907351
# [93]	validation's auc: 0.907351
# [94]	validation's auc: 0.906015
# [95]	validation's auc: 0.906683
# [96]	validation's auc: 0.907017
# [97]	validation's auc: 0.907251
# [98]	validation's auc: 0.907919
# [99]	validation's auc: 0.908787
# [100]	validation's auc: 0.908687
# [101]	validation's auc: 0.909088
# [102]	validation's auc: 0.908687
# [103]	validation's auc: 0.90852
# [104]	validation's auc: 0.909489
# [105]	validation's auc: 0.909856
# [106]	validation's auc: 0.909221
# [107]	validation's auc: 0.910023
# [108]	validation's auc: 0.909856
# [109]	validation's auc: 0.909622
# [110]	validation's auc: 0.910056
# [111]	validation's auc: 0.910357
# [112]	validation's auc: 0.910257
# [113]	validation's auc: 0.910223
# [114]	validation's auc: 0.910457
# [115]	validation's auc: 0.910457
# [116]	validation's auc: 0.909722
# [117]	validation's auc: 0.909422
# [118]	validation's auc: 0.909422
# [119]	validation's auc: 0.91009
# [120]	validation's auc: 0.909956
# [121]	validation's auc: 0.91019
# [122]	validation's auc: 0.910023
# [123]	validation's auc: 0.908754
# [124]	validation's auc: 0.909455
# [125]	validation's auc: 0.909088
# [126]	validation's auc: 0.909288
# [127]	validation's auc: 0.909388
# [128]	validation's auc: 0.909388
# [129]	validation's auc: 0.909021
# [130]	validation's auc: 0.909021
# [131]	validation's auc: 0.909221
# [132]	validation's auc: 0.909622
# [133]	validation's auc: 0.909088
# [134]	validation's auc: 0.909255
# [135]	validation's auc: 0.908921
# [136]	validation's auc: 0.909288
# [137]	validation's auc: 0.908553
# [138]	validation's auc: 0.90862
# [139]	validation's auc: 0.909555
# [140]	validation's auc: 0.909722
# [141]	validation's auc: 0.91009
# [142]	validation's auc: 0.910123
# [143]	validation's auc: 0.909889
# [144]	validation's auc: 0.909422
# [145]	validation's auc: 0.909589
# [146]	validation's auc: 0.909789
# [147]	validation's auc: 0.910691
# [148]	validation's auc: 0.910324
# [149]	validation's auc: 0.910023
# [150]	validation's auc: 0.909789
# [151]	validation's auc: 0.909489
# [152]	validation's auc: 0.909555
# [153]	validation's auc: 0.909054
# [154]	validation's auc: 0.908053
# [155]	validation's auc: 0.908253
# [156]	validation's auc: 0.907785
# [157]	validation's auc: 0.90832
# [158]	validation's auc: 0.907852
# [159]	validation's auc: 0.908253
# [160]	validation's auc: 0.907819
# [161]	validation's auc: 0.908086
# [162]	validation's auc: 0.908219
# [163]	validation's auc: 0.90842
# [164]	validation's auc: 0.908954
# [165]	validation's auc: 0.90872
# [166]	validation's auc: 0.908119
# [167]	validation's auc: 0.907919
# [168]	validation's auc: 0.907618
# [169]	validation's auc: 0.907685
# [170]	validation's auc: 0.908186
# [171]	validation's auc: 0.90872
# [172]	validation's auc: 0.909555
# [173]	validation's auc: 0.909656
# [174]	validation's auc: 0.909622
# [175]	validation's auc: 0.90999
# [176]	validation's auc: 0.909823
# [177]	validation's auc: 0.909221
# [178]	validation's auc: 0.909021
# [179]	validation's auc: 0.908988
# [180]	validation's auc: 0.909188
# [181]	validation's auc: 0.909689
# [182]	validation's auc: 0.908787
# [183]	validation's auc: 0.908787
# [184]	validation's auc: 0.909322
# [185]	validation's auc: 0.909221
# [186]	validation's auc: 0.909388
# [187]	validation's auc: 0.908988
# [188]	validation's auc: 0.909422
# [189]	validation's auc: 0.909489
# [190]	validation's auc: 0.908821
# [191]	validation's auc: 0.909155
# [192]	validation's auc: 0.909121
# [193]	validation's auc: 0.909021
# [194]	validation's auc: 0.909388
# [195]	validation's auc: 0.909756
# [196]	validation's auc: 0.909856
# [197]	validation's auc: 0.909722
# Early stopping, best iteration is:
# [147]	validation's auc: 0.910691
# best roc_auc: 0.933395387320302
# Accuracy: 96.40%
#               precision    recall  f1-score   support
#
#            0       0.96      0.99      0.98       672
#            1       0.96      0.90      0.93       244
#
#     accuracy                           0.96       916
#    macro avg       0.96      0.94      0.95       916
# weighted avg       0.96      0.96      0.96       916
#
# ############################################################################
# Accuracy 2021 to 2014 [97.38219895287958, 88.83677298311444, 91.73708920187794, 89.65517241379311, 91.27789046653145, 93.77637130801688, 92.15896885069817, 96.39737991266377]
#
#
# AUC 2021 to 2014 [0.9113262447014873, 0.9061326291079812, 0.9253022839229736, 0.9213008937437934, 0.93893344589841, 0.9208468869485819, 0.9276370887337986, 0.933395387320302]
#
#
# recall score 2021 to 2014 [0.9555555555555556, 0.7375, 0.7929936305732485, 0.7324414715719063, 0.7586206896551724, 0.8379310344827586, 0.7777777777777778, 0.8975409836065574]
#
#
# average recall of 1:  0.811295142902872
