# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import KFold, train_test_split
from sklearn.metrics import precision_recall_fscore_support,roc_auc_score
import lightgbm as lgb
import joblib
import warnings
warnings.filterwarnings("ignore")
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
from sklearn.metrics import recall_score
from functools import reduce
from pandas import DataFrame

# %%
list_year_test = ['2021','2020','2019','2018','2017','2016','2015','2014','2013','2012','2011','2010',
                  '2009','2008','2007','2006','2005','2004','2003']
list_year2_train = ['2020','2019','2018','2017','2016','2015','2014','2013','2012','2011','2010',
                  '2009','2008','2007','2006','2005','2004','2003','2002']
accuracy_list = []
auc_list = []
recall_list = []

def Average(lst):
    return reduce(lambda a, b: a + b, lst) / len(lst)

#for year in list_year:
for test_year1, train_year1 in zip(list_year_test, list_year2_train):
    print('############################################################################')
    print(test_year1)
    train_year = pd.read_csv(train_year1+'.csv') 
    test_year = pd.read_csv(test_year1+'.csv')
    df_ratios  = pd.concat([train_year, test_year])
    
    #rename columns
    df_rename = pd.read_excel('rename_file.xlsx')   
    for i in range(len(df_rename)):
        df_ratios = df_ratios.rename(columns={df_rename['Name1'][i]: df_rename['Name2'][i]})        
    
    
    #df_ratios.head()
    all_len = len(df_ratios.index)
    test_len = len(test_year.index)
    ratio_len = test_len/(all_len)
    # Display the structure
    #df_ratios.info()

    # Display the structure
    #df_ratios.info()

    # Normalization
    from sklearn import preprocessing
    min_max_scaler = preprocessing.MinMaxScaler()
    for i in df_ratios.columns[3:-12]:
        df_ratios[i] = min_max_scaler.fit_transform(df_ratios[[i]].to_numpy())*1000
        df_ratios[i] = df_ratios[i].apply(lambda x: np.log10(x + 0.01))
        ### this normalization is arbitrary, but should put all nos. in comparable basis of the same magnitude - can see the
        ###   describe statistics below
    #df_ratios.head(10)

    df_ratios_new=df_ratios

    X = df_ratios_new.iloc[:,3:-1]
    y = df_ratios_new.iloc[:,-1]

    Train, Test = train_test_split(df_ratios_new, test_size=ratio_len,shuffle=False)
    X_train, y_train = Train.iloc[:,3:-1], Train.iloc[:,-1]
    X_test, y_test = Test.iloc[:,3:-1], Test.iloc[:,-1]
    #print(y_test.dtype)
    #print(y_test)

    #y_test.shape[0]

    #len(df_ratios_new)

    #X_train.head()

    # hyper parameter setting
    #2^(max_depth) for num_leaves
    #huge number prevents overfitting.
    params = {'num_leaves':491,
              'min_data_in_leaf':106,
              'objective':'binary',# binary classification
              'max_depth':-1, # no limit
              'boosting_type':'gbdt',#'dart','goss','rf'
              'metric':'auc',
              'verbosity':-1
              #'random_state':42
    }

    # to save feature importance
    feature_importance = pd.DataFrame(index=None)

    feature_importance['features'] = X_train.columns

    feature_importance

    # k fold cross validation
    folds = KFold(n_splits=2)

    splits = folds.split(X,y)

    next(iter(splits))

    best_auc = 0
    best_model = None

    for k,(train_indices, val_indices) in enumerate(splits):
        #print(f'{k}th fold')
        X_train, X_val = X.iloc[train_indices], X.iloc[val_indices]
        y_train, y_val = y.iloc[train_indices], y.iloc[val_indices]

        train_dataset = lgb.Dataset(X_train,label=y_train)
        val_dataset = lgb.Dataset(X_val,label=y_val)

        lgb_model = lgb.train(
            params=params,
            train_set = train_dataset,
            #number of boosting iterations.
            num_boost_round = 10000,
            valid_sets = val_dataset,
            valid_names = 'validation',
            early_stopping_rounds = 50,
        )
        feature_importance[f'fold_{k+1}'] = lgb_model.feature_importance()

        y_val_pred = lgb_model.predict(X_val)

        roc_auc = roc_auc_score(y_val,y_val_pred)
        #print(f'fold {k+1} | AUC_ROC: {roc_auc *100}%')

        if roc_auc > best_auc:
            best_auc = roc_auc
            best_model = lgb_model

    #best_auc

    #feature_importance.head()

    feature_importance['average'] = feature_importance[[f'fold_{k+1}' for k in range (folds.n_splits-1)]].mean(axis=1)

    # visualize top 50 features
    plt.figure(figsize=(16,16))
    sns.barplot(data=feature_importance.sort_values(by='average',ascending=False).head(70),
               x='average',
               y='features')
    plt.title(f'top 70 features importances over {folds.n_splits-1} folds average.')
    plt.tight_layout()
    print('best roc_auc:', best_auc)

    Train, Test = train_test_split(df_ratios_new, test_size=ratio_len, shuffle=False)
    X_train, y_train = Train.iloc[:,3:-1], Train.iloc[:,-1]
    X_test, y_test = Test.iloc[:,3:-1], Test.iloc[:,-1]
    from sklearn.metrics import roc_auc_score
    from sklearn.metrics import roc_curve
    lgb_roc_auc = roc_auc_score(y_test, best_model.predict(X_test))
    lgb_roc_auc_train = roc_auc_score(y_train, best_model.predict(X_train))
    fpr, tpr, thresholds = roc_curve(y_test, best_model.predict(X_test))
    fpr_train, tpr_train, thresholds_train = roc_curve(y_train, best_model.predict(X_train))
    plt.figure()
    plt.plot(fpr, tpr, label='LGBM_test (area = %0.2f)' % lgb_roc_auc)
    plt.plot(fpr_train, tpr_train, label='LGBM_train (area = %0.2f)' % lgb_roc_auc_train)
    plt.plot([0, 1], [0, 1],'r--')
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('Receiver operating characteristic')
    plt.legend(loc="lower right")
    plt.show()

    from sklearn.metrics import accuracy_score
    y_pred = best_model.predict(X_test)
    predictions = [round(value) for value in y_pred]
    # evaluate predictions
    accuracy = accuracy_score(y_test, predictions)
    print("Accuracy: %.2f%%" % (accuracy * 100.0))
    accuracy_list.append(accuracy * 100.0)
    auc_list.append(best_auc)
    
    from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
    import sklearn.metrics as metrics
    confusion_matrix = confusion_matrix(y_test, predictions)
    cm_display = metrics.ConfusionMatrixDisplay(confusion_matrix = confusion_matrix, display_labels = [0, 1])
    cm_display.plot()
    plt.show()
    print(classification_report(y_test, predictions))
    recallScore = recall_score(y_test, predictions)
    recall_list.append(recallScore)     
    print('############################################################################')
    from sklearn.metrics import mean_squared_error
    rmse_L = (np.sqrt(mean_squared_error(y_test, y_pred)))
    print('rmse:', rmse_L)
    predictions_col = pd.DataFrame(data = predictions)
    test_year['predictions_col'] = predictions_col
    test_year['predictions_pass_fail'] = np.where((test_year['predictions_col']==1) & (test_year['RnD_OVER_TA_CAT'] == 0),'suspicious','pass')
print('Accuracy 2021 to 2003', accuracy_list)
print('')
print('')
print('AUC 2021 to 2003', auc_list)  
print('')
print('')
average_recall = Average(recall_list)
print('recall score 2021 to 2003', recall_list)
print('')
print('')
print('average recall of 1: ', average_recall)
# Out:
# ############################################################################
# 2021
# [1]	validation's auc: 0.907586
# Training until validation scores don't improve for 50 rounds
# [2]	validation's auc: 0.921436
# [3]	validation's auc: 0.92243
# [4]	validation's auc: 0.928062
# [5]	validation's auc: 0.931085
# [6]	validation's auc: 0.930947
# [7]	validation's auc: 0.931628
# [8]	validation's auc: 0.93253
# [9]	validation's auc: 0.933717
# [10]	validation's auc: 0.933901
# [11]	validation's auc: 0.934215
# [12]	validation's auc: 0.934362
# [13]	validation's auc: 0.934719
# [14]	validation's auc: 0.936067
# [15]	validation's auc: 0.935648
# [16]	validation's auc: 0.936404
# [17]	validation's auc: 0.937611
# [18]	validation's auc: 0.937663
# [19]	validation's auc: 0.938406
# [20]	validation's auc: 0.939207
# [21]	validation's auc: 0.940083
# [22]	validation's auc: 0.940338
# [23]	validation's auc: 0.940077
# [24]	validation's auc: 0.940825
# [25]	validation's auc: 0.942002
# [26]	validation's auc: 0.942399
# [27]	validation's auc: 0.942936
# [28]	validation's auc: 0.942863
# [29]	validation's auc: 0.943209
# [30]	validation's auc: 0.942914
# [31]	validation's auc: 0.943658
# [32]	validation's auc: 0.944144
# [33]	validation's auc: 0.944664
# [34]	validation's auc: 0.944741
# [35]	validation's auc: 0.94518
# [36]	validation's auc: 0.944963
# [37]	validation's auc: 0.945672
# [38]	validation's auc: 0.945896
# [39]	validation's auc: 0.946307
# [40]	validation's auc: 0.946404
# [41]	validation's auc: 0.946418
# [42]	validation's auc: 0.94667
# [43]	validation's auc: 0.946813
# [44]	validation's auc: 0.946935
# [45]	validation's auc: 0.947378
# [46]	validation's auc: 0.947692
# [47]	validation's auc: 0.947489
# [48]	validation's auc: 0.947781
# [49]	validation's auc: 0.947742
# [50]	validation's auc: 0.947568
# [51]	validation's auc: 0.947507
# [52]	validation's auc: 0.947573
# [53]	validation's auc: 0.947591
# [54]	validation's auc: 0.947741
# [55]	validation's auc: 0.947602
# [56]	validation's auc: 0.947724
# [57]	validation's auc: 0.947838
# [58]	validation's auc: 0.947894
# [59]	validation's auc: 0.947756
# [60]	validation's auc: 0.947727
# [61]	validation's auc: 0.947504
# [62]	validation's auc: 0.947828
# [63]	validation's auc: 0.947664
# [64]	validation's auc: 0.947742
# [65]	validation's auc: 0.947874
# [66]	validation's auc: 0.947747
# [67]	validation's auc: 0.947834
# [68]	validation's auc: 0.948008
# [69]	validation's auc: 0.947839
# [70]	validation's auc: 0.947781
# [71]	validation's auc: 0.947806
# [72]	validation's auc: 0.947922
# [73]	validation's auc: 0.948161
# [74]	validation's auc: 0.947878
# [75]	validation's auc: 0.948049
# [76]	validation's auc: 0.948152
# [77]	validation's auc: 0.948072
# [78]	validation's auc: 0.948141
# [79]	validation's auc: 0.94797
# [80]	validation's auc: 0.94806
# [81]	validation's auc: 0.947932
# [82]	validation's auc: 0.947985
# [83]	validation's auc: 0.948012
# [84]	validation's auc: 0.94834
# [85]	validation's auc: 0.948326
# [86]	validation's auc: 0.948313
# [87]	validation's auc: 0.948179
# [88]	validation's auc: 0.948187
# [89]	validation's auc: 0.94855
# [90]	validation's auc: 0.948476
# [91]	validation's auc: 0.948497
# [92]	validation's auc: 0.948482
# [93]	validation's auc: 0.948688
# [94]	validation's auc: 0.948915
# [95]	validation's auc: 0.94893
# [96]	validation's auc: 0.94883
# [97]	validation's auc: 0.948999
# [98]	validation's auc: 0.948884
# [99]	validation's auc: 0.948957
# [100]	validation's auc: 0.949019
# [101]	validation's auc: 0.949177
# [102]	validation's auc: 0.949382
# [103]	validation's auc: 0.949469
# [104]	validation's auc: 0.949593
# [105]	validation's auc: 0.949746
# [106]	validation's auc: 0.949796
# [107]	validation's auc: 0.950067
# [108]	validation's auc: 0.950147
# [109]	validation's auc: 0.950186
# [110]	validation's auc: 0.95029
# [111]	validation's auc: 0.950486
# [112]	validation's auc: 0.950751
# [113]	validation's auc: 0.950738
# [114]	validation's auc: 0.950816
# [115]	validation's auc: 0.950909
# [116]	validation's auc: 0.950974
# [117]	validation's auc: 0.950948
# [118]	validation's auc: 0.950942
# [119]	validation's auc: 0.951193
# [120]	validation's auc: 0.951256
# [121]	validation's auc: 0.951421
# [122]	validation's auc: 0.951462
# [123]	validation's auc: 0.951375
# [124]	validation's auc: 0.951465
# [125]	validation's auc: 0.951536
# [126]	validation's auc: 0.951378
# [127]	validation's auc: 0.951467
# [128]	validation's auc: 0.951347
# [129]	validation's auc: 0.951293
# [130]	validation's auc: 0.951572
# [131]	validation's auc: 0.95145
# [132]	validation's auc: 0.951539
# [133]	validation's auc: 0.951562
# [134]	validation's auc: 0.951728
# [135]	validation's auc: 0.951708
# [136]	validation's auc: 0.951761
# [137]	validation's auc: 0.951993
# [138]	validation's auc: 0.952138
# [139]	validation's auc: 0.952132
# [140]	validation's auc: 0.952079
# [141]	validation's auc: 0.952083
# [142]	validation's auc: 0.952128
# [143]	validation's auc: 0.952033
# [144]	validation's auc: 0.951974
# [145]	validation's auc: 0.952024
# [146]	validation's auc: 0.952058
# [147]	validation's auc: 0.952097
# [148]	validation's auc: 0.952208
# [149]	validation's auc: 0.952247
# [150]	validation's auc: 0.952418
# [151]	validation's auc: 0.952489
# [152]	validation's auc: 0.952514
# [153]	validation's auc: 0.952593
# [154]	validation's auc: 0.952512
# [155]	validation's auc: 0.952449
# [156]	validation's auc: 0.952454
# [157]	validation's auc: 0.952518
# [158]	validation's auc: 0.952654
# [159]	validation's auc: 0.952553
# [160]	validation's auc: 0.952565
# [161]	validation's auc: 0.952461
# [162]	validation's auc: 0.952559
# [163]	validation's auc: 0.952643
# [164]	validation's auc: 0.952573
# [165]	validation's auc: 0.952604
# [166]	validation's auc: 0.952576
# [167]	validation's auc: 0.952551
# [168]	validation's auc: 0.952615
# [169]	validation's auc: 0.95253
# [170]	validation's auc: 0.952504
# [171]	validation's auc: 0.952432
# [172]	validation's auc: 0.952447
# [173]	validation's auc: 0.952549
# [174]	validation's auc: 0.952587
# [175]	validation's auc: 0.952605
# [176]	validation's auc: 0.952724
# [177]	validation's auc: 0.952707
# [178]	validation's auc: 0.952811
# [179]	validation's auc: 0.952741
# [180]	validation's auc: 0.95274
# [181]	validation's auc: 0.952804
# [182]	validation's auc: 0.952748
# [183]	validation's auc: 0.952736
# [184]	validation's auc: 0.952632
# [185]	validation's auc: 0.952724
# [186]	validation's auc: 0.952777
# [187]	validation's auc: 0.952699
# [188]	validation's auc: 0.952909
# [189]	validation's auc: 0.953003
# [190]	validation's auc: 0.953075
# [191]	validation's auc: 0.9531
# [192]	validation's auc: 0.953125
# [193]	validation's auc: 0.953149
# [194]	validation's auc: 0.953143
# [195]	validation's auc: 0.953122
# [196]	validation's auc: 0.953046
# [197]	validation's auc: 0.952991
# [198]	validation's auc: 0.952886
# [199]	validation's auc: 0.952701
# [200]	validation's auc: 0.952789
# [201]	validation's auc: 0.952769
# [202]	validation's auc: 0.952736
# [203]	validation's auc: 0.952688
# [204]	validation's auc: 0.952813
# [205]	validation's auc: 0.952824
# [206]	validation's auc: 0.952745
# [207]	validation's auc: 0.952813
# [208]	validation's auc: 0.952835
# [209]	validation's auc: 0.952847
# [210]	validation's auc: 0.95276
# [211]	validation's auc: 0.952659
# [212]	validation's auc: 0.952691
# [213]	validation's auc: 0.952727
# [214]	validation's auc: 0.952765
# [215]	validation's auc: 0.952711
# [216]	validation's auc: 0.952609
# [217]	validation's auc: 0.952499
# [218]	validation's auc: 0.95256
# [219]	validation's auc: 0.952586
# [220]	validation's auc: 0.952576
# [221]	validation's auc: 0.952548
# [222]	validation's auc: 0.952637
# [223]	validation's auc: 0.952582
# [224]	validation's auc: 0.95255
# [225]	validation's auc: 0.952502
# [226]	validation's auc: 0.952486
# [227]	validation's auc: 0.952419
# [228]	validation's auc: 0.952501
# [229]	validation's auc: 0.952455
# [230]	validation's auc: 0.952528
# [231]	validation's auc: 0.952449
# [232]	validation's auc: 0.952529
# [233]	validation's auc: 0.952472
# [234]	validation's auc: 0.952357
# [235]	validation's auc: 0.95235
# [236]	validation's auc: 0.952291
# [237]	validation's auc: 0.952377
# [238]	validation's auc: 0.952503
# [239]	validation's auc: 0.952361
# [240]	validation's auc: 0.952391
# [241]	validation's auc: 0.952463
# [242]	validation's auc: 0.952586
# [243]	validation's auc: 0.952541
# Early stopping, best iteration is:
# [193]	validation's auc: 0.953149
# best roc_auc: 0.9531493522362336
# Accuracy: 89.17%
#               precision    recall  f1-score   support
#
#            0       0.92      0.93      0.93      3238
#            1       0.82      0.78      0.80      1250
#
#     accuracy                           0.89      4488
#    macro avg       0.87      0.86      0.86      4488
# weighted avg       0.89      0.89      0.89      4488
#
# ############################################################################
# rmse: 0.2778758697313002
# ############################################################################
# 2020
# [1]	validation's auc: 0.893699
# Training until validation scores don't improve for 50 rounds
# [2]	validation's auc: 0.907023
# [3]	validation's auc: 0.907557
# [4]	validation's auc: 0.911805
# [5]	validation's auc: 0.916738
# [6]	validation's auc: 0.918402
# [7]	validation's auc: 0.919473
# [8]	validation's auc: 0.920324
# [9]	validation's auc: 0.920986
# [10]	validation's auc: 0.921429
# [11]	validation's auc: 0.922294
# [12]	validation's auc: 0.924196
# [13]	validation's auc: 0.925878
# [14]	validation's auc: 0.926362
# [15]	validation's auc: 0.927639
# [16]	validation's auc: 0.928074
# [17]	validation's auc: 0.929745
# [18]	validation's auc: 0.9317
# [19]	validation's auc: 0.932448
# [20]	validation's auc: 0.933717
# [21]	validation's auc: 0.933937
# [22]	validation's auc: 0.934271
# [23]	validation's auc: 0.935355
# [24]	validation's auc: 0.935453
# [25]	validation's auc: 0.936515
# [26]	validation's auc: 0.937339
# [27]	validation's auc: 0.938005
# [28]	validation's auc: 0.938763
# [29]	validation's auc: 0.938931
# [30]	validation's auc: 0.939733
# [31]	validation's auc: 0.940085
# [32]	validation's auc: 0.940573
# [33]	validation's auc: 0.940941
# [34]	validation's auc: 0.941497
# [35]	validation's auc: 0.941397
# [36]	validation's auc: 0.94201
# [37]	validation's auc: 0.942278
# [38]	validation's auc: 0.94282
# [39]	validation's auc: 0.943044
# [40]	validation's auc: 0.943112
# [41]	validation's auc: 0.943139
# [42]	validation's auc: 0.943365
# [43]	validation's auc: 0.943373
# [44]	validation's auc: 0.943347
# [45]	validation's auc: 0.943938
# [46]	validation's auc: 0.944092
# [47]	validation's auc: 0.944489
# [48]	validation's auc: 0.944806
# [49]	validation's auc: 0.944698
# [50]	validation's auc: 0.945121
# [51]	validation's auc: 0.945157
# [52]	validation's auc: 0.945245
# [53]	validation's auc: 0.945333
# [54]	validation's auc: 0.945624
# [55]	validation's auc: 0.945827
# [56]	validation's auc: 0.946011
# [57]	validation's auc: 0.946218
# [58]	validation's auc: 0.946666
# [59]	validation's auc: 0.946645
# [60]	validation's auc: 0.946454
# [61]	validation's auc: 0.946391
# [62]	validation's auc: 0.946624
# [63]	validation's auc: 0.946682
# [64]	validation's auc: 0.946755
# [65]	validation's auc: 0.946657
# [66]	validation's auc: 0.946943
# [67]	validation's auc: 0.947098
# [68]	validation's auc: 0.947259
# [69]	validation's auc: 0.947478
# [70]	validation's auc: 0.947736
# [71]	validation's auc: 0.947805
# [72]	validation's auc: 0.947816
# [73]	validation's auc: 0.947882
# [74]	validation's auc: 0.947969
# [75]	validation's auc: 0.948056
# [76]	validation's auc: 0.94802
# [77]	validation's auc: 0.948367
# [78]	validation's auc: 0.948501
# [79]	validation's auc: 0.948359
# [80]	validation's auc: 0.948407
# [81]	validation's auc: 0.948447
# [82]	validation's auc: 0.94851
# [83]	validation's auc: 0.948615
# [84]	validation's auc: 0.948712
# [85]	validation's auc: 0.948822
# [86]	validation's auc: 0.949136
# [87]	validation's auc: 0.949288
# [88]	validation's auc: 0.949363
# [89]	validation's auc: 0.949298
# [90]	validation's auc: 0.949165
# [91]	validation's auc: 0.949177
# [92]	validation's auc: 0.949228
# [93]	validation's auc: 0.949334
# [94]	validation's auc: 0.949361
# [95]	validation's auc: 0.94926
# [96]	validation's auc: 0.949338
# [97]	validation's auc: 0.949447
# [98]	validation's auc: 0.949646
# [99]	validation's auc: 0.949748
# [100]	validation's auc: 0.949867
# [101]	validation's auc: 0.949936
# [102]	validation's auc: 0.949795
# [103]	validation's auc: 0.949847
# [104]	validation's auc: 0.94983
# [105]	validation's auc: 0.94995
# [106]	validation's auc: 0.950071
# [107]	validation's auc: 0.950205
# [108]	validation's auc: 0.950159
# [109]	validation's auc: 0.950174
# [110]	validation's auc: 0.950233
# [111]	validation's auc: 0.950472
# [112]	validation's auc: 0.950687
# [113]	validation's auc: 0.950522
# [114]	validation's auc: 0.950446
# [115]	validation's auc: 0.95039
# [116]	validation's auc: 0.950409
# [117]	validation's auc: 0.95042
# [118]	validation's auc: 0.950535
# [119]	validation's auc: 0.950613
# [120]	validation's auc: 0.950788
# [121]	validation's auc: 0.950937
# [122]	validation's auc: 0.950738
# [123]	validation's auc: 0.950727
# [124]	validation's auc: 0.950777
# [125]	validation's auc: 0.950761
# [126]	validation's auc: 0.950769
# [127]	validation's auc: 0.950832
# [128]	validation's auc: 0.950857
# [129]	validation's auc: 0.950809
# [130]	validation's auc: 0.950875
# [131]	validation's auc: 0.950823
# [132]	validation's auc: 0.950813
# [133]	validation's auc: 0.950784
# [134]	validation's auc: 0.950891
# [135]	validation's auc: 0.95097
# [136]	validation's auc: 0.95085
# [137]	validation's auc: 0.95088
# [138]	validation's auc: 0.950832
# [139]	validation's auc: 0.950995
# [140]	validation's auc: 0.950813
# [141]	validation's auc: 0.950873
# [142]	validation's auc: 0.950948
# [143]	validation's auc: 0.950908
# [144]	validation's auc: 0.950849
# [145]	validation's auc: 0.950876
# [146]	validation's auc: 0.950848
# [147]	validation's auc: 0.950676
# [148]	validation's auc: 0.950787
# [149]	validation's auc: 0.95061
# [150]	validation's auc: 0.950636
# [151]	validation's auc: 0.950542
# [152]	validation's auc: 0.950679
# [153]	validation's auc: 0.950642
# [154]	validation's auc: 0.950532
# [155]	validation's auc: 0.950675
# [156]	validation's auc: 0.950645
# [157]	validation's auc: 0.950549
# [158]	validation's auc: 0.950632
# [159]	validation's auc: 0.950664
# [160]	validation's auc: 0.950719
# [161]	validation's auc: 0.950683
# [162]	validation's auc: 0.9506
# [163]	validation's auc: 0.950436
# [164]	validation's auc: 0.950539
# [165]	validation's auc: 0.950668
# [166]	validation's auc: 0.950689
# [167]	validation's auc: 0.950873
# [168]	validation's auc: 0.950904
# [169]	validation's auc: 0.95081
# [170]	validation's auc: 0.950733
# [171]	validation's auc: 0.950905
# [172]	validation's auc: 0.950972
# [173]	validation's auc: 0.951033
# [174]	validation's auc: 0.951196
# [175]	validation's auc: 0.951283
# [176]	validation's auc: 0.951328
# [177]	validation's auc: 0.951466
# [178]	validation's auc: 0.95146
# [179]	validation's auc: 0.951198
# [180]	validation's auc: 0.951237
# [181]	validation's auc: 0.951154
# [182]	validation's auc: 0.951078
# [183]	validation's auc: 0.951145
# [184]	validation's auc: 0.951239
# [185]	validation's auc: 0.951238
# [186]	validation's auc: 0.951388
# [187]	validation's auc: 0.951295
# [188]	validation's auc: 0.951271
# [189]	validation's auc: 0.951336
# [190]	validation's auc: 0.95134
# [191]	validation's auc: 0.951293
# [192]	validation's auc: 0.951102
# [193]	validation's auc: 0.951179
# [194]	validation's auc: 0.951166
# [195]	validation's auc: 0.951191
# [196]	validation's auc: 0.95106
# [197]	validation's auc: 0.951005
# [198]	validation's auc: 0.951013
# [199]	validation's auc: 0.951029
# [200]	validation's auc: 0.950893
# [201]	validation's auc: 0.950935
# [202]	validation's auc: 0.950999
# [203]	validation's auc: 0.951011
# [204]	validation's auc: 0.951024
# [205]	validation's auc: 0.950953
# [206]	validation's auc: 0.951013
# [207]	validation's auc: 0.950985
# [208]	validation's auc: 0.950911
# [209]	validation's auc: 0.950958
# [210]	validation's auc: 0.951068
# [211]	validation's auc: 0.951046
# [212]	validation's auc: 0.951008
# [213]	validation's auc: 0.951141
# [214]	validation's auc: 0.95115
# [215]	validation's auc: 0.95109
# [216]	validation's auc: 0.951084
# [217]	validation's auc: 0.951159
# [218]	validation's auc: 0.9512
# [219]	validation's auc: 0.951229
# [220]	validation's auc: 0.951363
# [221]	validation's auc: 0.951467
# [222]	validation's auc: 0.951612
# [223]	validation's auc: 0.95167
# [224]	validation's auc: 0.951786
# [225]	validation's auc: 0.951829
# [226]	validation's auc: 0.951909
# [227]	validation's auc: 0.951766
# [228]	validation's auc: 0.95184
# [229]	validation's auc: 0.951863
# [230]	validation's auc: 0.951815
# [231]	validation's auc: 0.951884
# [232]	validation's auc: 0.951881
# [233]	validation's auc: 0.951858
# [234]	validation's auc: 0.951957
# [235]	validation's auc: 0.952009
# [236]	validation's auc: 0.952029
# [237]	validation's auc: 0.952075
# [238]	validation's auc: 0.952127
# [239]	validation's auc: 0.952157
# [240]	validation's auc: 0.952006
# [241]	validation's auc: 0.952045
# [242]	validation's auc: 0.951966
# [243]	validation's auc: 0.951997
# [244]	validation's auc: 0.95205
# [245]	validation's auc: 0.952173
# [246]	validation's auc: 0.952147
# [247]	validation's auc: 0.952163
# [248]	validation's auc: 0.95211
# [249]	validation's auc: 0.952105
# [250]	validation's auc: 0.95221
# [251]	validation's auc: 0.952285
# [252]	validation's auc: 0.952247
# [253]	validation's auc: 0.952133
# [254]	validation's auc: 0.952017
# [255]	validation's auc: 0.951958
# [256]	validation's auc: 0.951959
# [257]	validation's auc: 0.951933
# [258]	validation's auc: 0.95202
# [259]	validation's auc: 0.952018
# [260]	validation's auc: 0.952229
# [261]	validation's auc: 0.952205
# [262]	validation's auc: 0.952134
# [263]	validation's auc: 0.952081
# [264]	validation's auc: 0.952136
# [265]	validation's auc: 0.95209
# [266]	validation's auc: 0.952051
# [267]	validation's auc: 0.952093
# [268]	validation's auc: 0.952174
# [269]	validation's auc: 0.952009
# [270]	validation's auc: 0.951913
# [271]	validation's auc: 0.951914
# [272]	validation's auc: 0.951945
# [273]	validation's auc: 0.951921
# [274]	validation's auc: 0.951975
# [275]	validation's auc: 0.9521
# [276]	validation's auc: 0.95209
# [277]	validation's auc: 0.95207
# [278]	validation's auc: 0.952004
# [279]	validation's auc: 0.95204
# [280]	validation's auc: 0.952042
# [281]	validation's auc: 0.95208
# [282]	validation's auc: 0.952094
# [283]	validation's auc: 0.952105
# [284]	validation's auc: 0.952246
# [285]	validation's auc: 0.952211
# [286]	validation's auc: 0.952309
# [287]	validation's auc: 0.95231
# [288]	validation's auc: 0.9523
# [289]	validation's auc: 0.952344
# [290]	validation's auc: 0.952326
# [291]	validation's auc: 0.952253
# [292]	validation's auc: 0.952277
# [293]	validation's auc: 0.952245
# [294]	validation's auc: 0.952382
# [295]	validation's auc: 0.952369
# [296]	validation's auc: 0.952443
# [297]	validation's auc: 0.952419
# [298]	validation's auc: 0.952424
# [299]	validation's auc: 0.952427
# [300]	validation's auc: 0.952367
# [301]	validation's auc: 0.95234
# [302]	validation's auc: 0.9523
# [303]	validation's auc: 0.952309
# [304]	validation's auc: 0.952318
# [305]	validation's auc: 0.952401
# [306]	validation's auc: 0.9524
# [307]	validation's auc: 0.952356
# [308]	validation's auc: 0.952372
# [309]	validation's auc: 0.952414
# [310]	validation's auc: 0.952368
# [311]	validation's auc: 0.952371
# [312]	validation's auc: 0.952361
# [313]	validation's auc: 0.952377
# [314]	validation's auc: 0.952362
# [315]	validation's auc: 0.952397
# [316]	validation's auc: 0.952327
# [317]	validation's auc: 0.952399
# [318]	validation's auc: 0.952361
# [319]	validation's auc: 0.952421
# [320]	validation's auc: 0.952337
# [321]	validation's auc: 0.952371
# [322]	validation's auc: 0.952329
# [323]	validation's auc: 0.952386
# [324]	validation's auc: 0.952423
# [325]	validation's auc: 0.952442
# [326]	validation's auc: 0.952432
# [327]	validation's auc: 0.952519
# [328]	validation's auc: 0.952453
# [329]	validation's auc: 0.952455
# [330]	validation's auc: 0.952391
# [331]	validation's auc: 0.952374
# [332]	validation's auc: 0.952411
# [333]	validation's auc: 0.952325
# [334]	validation's auc: 0.952371
# [335]	validation's auc: 0.952301
# [336]	validation's auc: 0.952273
# [337]	validation's auc: 0.952218
# [338]	validation's auc: 0.952168
# [339]	validation's auc: 0.952161
# [340]	validation's auc: 0.952125
# [341]	validation's auc: 0.95213
# [342]	validation's auc: 0.952034
# [343]	validation's auc: 0.951921
# [344]	validation's auc: 0.951967
# [345]	validation's auc: 0.951899
# [346]	validation's auc: 0.951943
# [347]	validation's auc: 0.951928
# [348]	validation's auc: 0.951879
# [349]	validation's auc: 0.951912
# [350]	validation's auc: 0.951878
# [351]	validation's auc: 0.951911
# [352]	validation's auc: 0.951946
# [353]	validation's auc: 0.951952
# [354]	validation's auc: 0.951999
# [355]	validation's auc: 0.952013
# [356]	validation's auc: 0.951947
# [357]	validation's auc: 0.952018
# [358]	validation's auc: 0.952007
# [359]	validation's auc: 0.952049
# [360]	validation's auc: 0.951956
# [361]	validation's auc: 0.952003
# [362]	validation's auc: 0.952059
# [363]	validation's auc: 0.95215
# [364]	validation's auc: 0.952225
# [365]	validation's auc: 0.952174
# [366]	validation's auc: 0.952242
# [367]	validation's auc: 0.95229
# [368]	validation's auc: 0.952208
# [369]	validation's auc: 0.952126
# [370]	validation's auc: 0.952189
# [371]	validation's auc: 0.952244
# [372]	validation's auc: 0.952199
# [373]	validation's auc: 0.952213
# [374]	validation's auc: 0.952239
# [375]	validation's auc: 0.952258
# [376]	validation's auc: 0.952239
# [377]	validation's auc: 0.952182
# Early stopping, best iteration is:
# [327]	validation's auc: 0.952519
# best roc_auc: 0.9525186911511104
# Accuracy: 89.05%
#               precision    recall  f1-score   support
#
#            0       0.91      0.94      0.92      3046
#            1       0.85      0.76      0.80      1246
#
#     accuracy                           0.89      4292
#    macro avg       0.88      0.85      0.86      4292
# weighted avg       0.89      0.89      0.89      4292
#
# ############################################################################
# rmse: 0.28541100574028144
# ############################################################################
# 2019
# [1]	validation's auc: 0.905429
# Training until validation scores don't improve for 50 rounds
# [2]	validation's auc: 0.911088
# [3]	validation's auc: 0.916491
# [4]	validation's auc: 0.917094
# [5]	validation's auc: 0.920944
# [6]	validation's auc: 0.922245
# [7]	validation's auc: 0.92282
# [8]	validation's auc: 0.922923
# [9]	validation's auc: 0.924162
# [10]	validation's auc: 0.92615
# [11]	validation's auc: 0.926087
# [12]	validation's auc: 0.927353
# [13]	validation's auc: 0.927523
# [14]	validation's auc: 0.927985
# [15]	validation's auc: 0.929068
# [16]	validation's auc: 0.92968
# [17]	validation's auc: 0.93073
# [18]	validation's auc: 0.931139
# [19]	validation's auc: 0.932117
# [20]	validation's auc: 0.933522
# [21]	validation's auc: 0.934185
# [22]	validation's auc: 0.934126
# [23]	validation's auc: 0.934281
# [24]	validation's auc: 0.934849
# [25]	validation's auc: 0.935352
# [26]	validation's auc: 0.935838
# [27]	validation's auc: 0.936182
# [28]	validation's auc: 0.936419
# [29]	validation's auc: 0.936523
# [30]	validation's auc: 0.937219
# [31]	validation's auc: 0.937518
# [32]	validation's auc: 0.938241
# [33]	validation's auc: 0.938968
# [34]	validation's auc: 0.939308
# [35]	validation's auc: 0.939265
# [36]	validation's auc: 0.939561
# [37]	validation's auc: 0.939418
# [38]	validation's auc: 0.939837
# [39]	validation's auc: 0.940177
# [40]	validation's auc: 0.940338
# [41]	validation's auc: 0.940169
# [42]	validation's auc: 0.939902
# [43]	validation's auc: 0.940321
# [44]	validation's auc: 0.940213
# [45]	validation's auc: 0.940028
# [46]	validation's auc: 0.940021
# [47]	validation's auc: 0.940245
# [48]	validation's auc: 0.940236
# [49]	validation's auc: 0.940376
# [50]	validation's auc: 0.940516
# [51]	validation's auc: 0.940841
# [52]	validation's auc: 0.941065
# [53]	validation's auc: 0.941241
# [54]	validation's auc: 0.941397
# [55]	validation's auc: 0.941524
# [56]	validation's auc: 0.941375
# [57]	validation's auc: 0.941489
# [58]	validation's auc: 0.94178
# [59]	validation's auc: 0.942118
# [60]	validation's auc: 0.942505
# [61]	validation's auc: 0.942223
# [62]	validation's auc: 0.942598
# [63]	validation's auc: 0.942782
# [64]	validation's auc: 0.942929
# [65]	validation's auc: 0.9427
# [66]	validation's auc: 0.94265
# [67]	validation's auc: 0.942539
# [68]	validation's auc: 0.942388
# [69]	validation's auc: 0.942351
# [70]	validation's auc: 0.942181
# [71]	validation's auc: 0.942276
# [72]	validation's auc: 0.942403
# [73]	validation's auc: 0.942242
# [74]	validation's auc: 0.94186
# [75]	validation's auc: 0.941952
# [76]	validation's auc: 0.942057
# [77]	validation's auc: 0.942324
# [78]	validation's auc: 0.942153
# [79]	validation's auc: 0.942507
# [80]	validation's auc: 0.942552
# [81]	validation's auc: 0.94224
# [82]	validation's auc: 0.942697
# [83]	validation's auc: 0.942953
# [84]	validation's auc: 0.942697
# [85]	validation's auc: 0.942779
# [86]	validation's auc: 0.942652
# [87]	validation's auc: 0.942637
# [88]	validation's auc: 0.942497
# [89]	validation's auc: 0.942288
# [90]	validation's auc: 0.942256
# [91]	validation's auc: 0.94201
# [92]	validation's auc: 0.941942
# [93]	validation's auc: 0.942002
# [94]	validation's auc: 0.942158
# [95]	validation's auc: 0.94193
# [96]	validation's auc: 0.941938
# [97]	validation's auc: 0.942125
# [98]	validation's auc: 0.942232
# [99]	validation's auc: 0.942338
# [100]	validation's auc: 0.942177
# [101]	validation's auc: 0.942212
# [102]	validation's auc: 0.942375
# [103]	validation's auc: 0.942386
# [104]	validation's auc: 0.942418
# [105]	validation's auc: 0.942264
# [106]	validation's auc: 0.942262
# [107]	validation's auc: 0.942307
# [108]	validation's auc: 0.94236
# [109]	validation's auc: 0.942195
# [110]	validation's auc: 0.942203
# [111]	validation's auc: 0.942228
# [112]	validation's auc: 0.94219
# [113]	validation's auc: 0.94204
# [114]	validation's auc: 0.941757
# [115]	validation's auc: 0.941985
# [116]	validation's auc: 0.941941
# [117]	validation's auc: 0.941983
# [118]	validation's auc: 0.941985
# [119]	validation's auc: 0.942109
# [120]	validation's auc: 0.94211
# [121]	validation's auc: 0.942219
# [122]	validation's auc: 0.942248
# [123]	validation's auc: 0.942204
# [124]	validation's auc: 0.942337
# [125]	validation's auc: 0.942466
# [126]	validation's auc: 0.942578
# [127]	validation's auc: 0.942475
# [128]	validation's auc: 0.942382
# [129]	validation's auc: 0.942427
# [130]	validation's auc: 0.942531
# [131]	validation's auc: 0.942558
# [132]	validation's auc: 0.942642
# [133]	validation's auc: 0.942745
# Early stopping, best iteration is:
# [83]	validation's auc: 0.942953
# best roc_auc: 0.9429531152559669
# Accuracy: 87.71%
#               precision    recall  f1-score   support
#
#            0       0.89      0.94      0.92      2922
#            1       0.84      0.72      0.78      1219
#
#     accuracy                           0.88      4141
#    macro avg       0.86      0.83      0.85      4141
# weighted avg       0.87      0.88      0.87      4141
#
# ############################################################################
# rmse: 0.2891158467690891
# ############################################################################
# 2018
# [1]	validation's auc: 0.872957
# Training until validation scores don't improve for 50 rounds
# [2]	validation's auc: 0.897686
# [3]	validation's auc: 0.900962
# [4]	validation's auc: 0.906336
# [5]	validation's auc: 0.912499
# [6]	validation's auc: 0.915603
# [7]	validation's auc: 0.918321
# [8]	validation's auc: 0.921018
# [9]	validation's auc: 0.921455
# [10]	validation's auc: 0.922763
# [11]	validation's auc: 0.92321
# [12]	validation's auc: 0.924116
# [13]	validation's auc: 0.925335
# [14]	validation's auc: 0.925916
# [15]	validation's auc: 0.926065
# [16]	validation's auc: 0.92657
# [17]	validation's auc: 0.927176
# [18]	validation's auc: 0.92753
# [19]	validation's auc: 0.928667
# [20]	validation's auc: 0.929928
# [21]	validation's auc: 0.930982
# [22]	validation's auc: 0.931474
# [23]	validation's auc: 0.931974
# [24]	validation's auc: 0.932611
# [25]	validation's auc: 0.932659
# [26]	validation's auc: 0.933529
# [27]	validation's auc: 0.933524
# [28]	validation's auc: 0.933673
# [29]	validation's auc: 0.934023
# [30]	validation's auc: 0.934591
# [31]	validation's auc: 0.935106
# [32]	validation's auc: 0.935894
# [33]	validation's auc: 0.935925
# [34]	validation's auc: 0.936508
# [35]	validation's auc: 0.936614
# [36]	validation's auc: 0.937127
# [37]	validation's auc: 0.937406
# [38]	validation's auc: 0.937479
# [39]	validation's auc: 0.937946
# [40]	validation's auc: 0.93778
# [41]	validation's auc: 0.937972
# [42]	validation's auc: 0.938006
# [43]	validation's auc: 0.93787
# [44]	validation's auc: 0.938205
# [45]	validation's auc: 0.938847
# [46]	validation's auc: 0.93929
# [47]	validation's auc: 0.939597
# [48]	validation's auc: 0.940012
# [49]	validation's auc: 0.94041
# [50]	validation's auc: 0.940574
# [51]	validation's auc: 0.940665
# [52]	validation's auc: 0.940897
# [53]	validation's auc: 0.941512
# [54]	validation's auc: 0.941553
# [55]	validation's auc: 0.941721
# [56]	validation's auc: 0.941785
# [57]	validation's auc: 0.941761
# [58]	validation's auc: 0.942127
# [59]	validation's auc: 0.942241
# [60]	validation's auc: 0.941944
# [61]	validation's auc: 0.942334
# [62]	validation's auc: 0.942035
# [63]	validation's auc: 0.942002
# [64]	validation's auc: 0.942175
# [65]	validation's auc: 0.942493
# [66]	validation's auc: 0.942772
# [67]	validation's auc: 0.943241
# [68]	validation's auc: 0.943302
# [69]	validation's auc: 0.943237
# [70]	validation's auc: 0.943152
# [71]	validation's auc: 0.943031
# [72]	validation's auc: 0.943428
# [73]	validation's auc: 0.94349
# [74]	validation's auc: 0.943497
# [75]	validation's auc: 0.943358
# [76]	validation's auc: 0.943356
# [77]	validation's auc: 0.943469
# [78]	validation's auc: 0.943664
# [79]	validation's auc: 0.943838
# [80]	validation's auc: 0.943632
# [81]	validation's auc: 0.943685
# [82]	validation's auc: 0.943939
# [83]	validation's auc: 0.944041
# [84]	validation's auc: 0.944072
# [85]	validation's auc: 0.944129
# [86]	validation's auc: 0.94426
# [87]	validation's auc: 0.944392
# [88]	validation's auc: 0.944614
# [89]	validation's auc: 0.944867
# [90]	validation's auc: 0.944914
# [91]	validation's auc: 0.945086
# [92]	validation's auc: 0.945322
# [93]	validation's auc: 0.945127
# [94]	validation's auc: 0.944961
# [95]	validation's auc: 0.945038
# [96]	validation's auc: 0.945256
# [97]	validation's auc: 0.945322
# [98]	validation's auc: 0.945567
# [99]	validation's auc: 0.945598
# [100]	validation's auc: 0.945745
# [101]	validation's auc: 0.945637
# [102]	validation's auc: 0.946012
# [103]	validation's auc: 0.94606
# [104]	validation's auc: 0.946055
# [105]	validation's auc: 0.946141
# [106]	validation's auc: 0.94642
# [107]	validation's auc: 0.946709
# [108]	validation's auc: 0.946851
# [109]	validation's auc: 0.946938
# [110]	validation's auc: 0.946924
# [111]	validation's auc: 0.946782
# [112]	validation's auc: 0.946875
# [113]	validation's auc: 0.94696
# [114]	validation's auc: 0.946864
# [115]	validation's auc: 0.946729
# [116]	validation's auc: 0.946668
# [117]	validation's auc: 0.946702
# [118]	validation's auc: 0.94666
# [119]	validation's auc: 0.946876
# [120]	validation's auc: 0.946978
# [121]	validation's auc: 0.946827
# [122]	validation's auc: 0.946776
# [123]	validation's auc: 0.946756
# [124]	validation's auc: 0.946981
# [125]	validation's auc: 0.947006
# [126]	validation's auc: 0.947104
# [127]	validation's auc: 0.947069
# [128]	validation's auc: 0.947301
# [129]	validation's auc: 0.947308
# [130]	validation's auc: 0.947343
# [131]	validation's auc: 0.947409
# [132]	validation's auc: 0.947337
# [133]	validation's auc: 0.94734
# [134]	validation's auc: 0.947241
# [135]	validation's auc: 0.947126
# [136]	validation's auc: 0.947047
# [137]	validation's auc: 0.947182
# [138]	validation's auc: 0.947098
# [139]	validation's auc: 0.947224
# [140]	validation's auc: 0.947286
# [141]	validation's auc: 0.947433
# [142]	validation's auc: 0.947576
# [143]	validation's auc: 0.947687
# [144]	validation's auc: 0.947631
# [145]	validation's auc: 0.947668
# [146]	validation's auc: 0.947596
# [147]	validation's auc: 0.947738
# [148]	validation's auc: 0.948016
# [149]	validation's auc: 0.947999
# [150]	validation's auc: 0.947924
# [151]	validation's auc: 0.947799
# [152]	validation's auc: 0.947802
# [153]	validation's auc: 0.947988
# [154]	validation's auc: 0.947887
# [155]	validation's auc: 0.947762
# [156]	validation's auc: 0.947931
# [157]	validation's auc: 0.948088
# [158]	validation's auc: 0.94797
# [159]	validation's auc: 0.947904
# [160]	validation's auc: 0.947824
# [161]	validation's auc: 0.94799
# [162]	validation's auc: 0.947968
# [163]	validation's auc: 0.948041
# [164]	validation's auc: 0.948145
# [165]	validation's auc: 0.948252
# [166]	validation's auc: 0.948244
# [167]	validation's auc: 0.948225
# [168]	validation's auc: 0.948094
# [169]	validation's auc: 0.948014
# [170]	validation's auc: 0.94804
# [171]	validation's auc: 0.947987
# [172]	validation's auc: 0.94795
# [173]	validation's auc: 0.94804
# [174]	validation's auc: 0.94803
# [175]	validation's auc: 0.948074
# [176]	validation's auc: 0.948172
# [177]	validation's auc: 0.948174
# [178]	validation's auc: 0.948277
# [179]	validation's auc: 0.948335
# [180]	validation's auc: 0.948387
# [181]	validation's auc: 0.948209
# [182]	validation's auc: 0.948094
# [183]	validation's auc: 0.948061
# [184]	validation's auc: 0.947999
# [185]	validation's auc: 0.948031
# [186]	validation's auc: 0.94796
# [187]	validation's auc: 0.947921
# [188]	validation's auc: 0.947828
# [189]	validation's auc: 0.947973
# [190]	validation's auc: 0.947971
# [191]	validation's auc: 0.947816
# [192]	validation's auc: 0.947849
# [193]	validation's auc: 0.947929
# [194]	validation's auc: 0.948124
# [195]	validation's auc: 0.948133
# [196]	validation's auc: 0.94826
# [197]	validation's auc: 0.948261
# [198]	validation's auc: 0.948281
# [199]	validation's auc: 0.948543
# [200]	validation's auc: 0.948451
# [201]	validation's auc: 0.948536
# [202]	validation's auc: 0.948412
# [203]	validation's auc: 0.948266
# [204]	validation's auc: 0.948161
# [205]	validation's auc: 0.948167
# [206]	validation's auc: 0.948114
# [207]	validation's auc: 0.94829
# [208]	validation's auc: 0.948212
# [209]	validation's auc: 0.948337
# [210]	validation's auc: 0.948303
# [211]	validation's auc: 0.94826
# [212]	validation's auc: 0.948263
# [213]	validation's auc: 0.948232
# [214]	validation's auc: 0.948097
# [215]	validation's auc: 0.947996
# [216]	validation's auc: 0.948104
# [217]	validation's auc: 0.948169
# [218]	validation's auc: 0.948155
# [219]	validation's auc: 0.948185
# [220]	validation's auc: 0.948089
# [221]	validation's auc: 0.948142
# [222]	validation's auc: 0.948019
# [223]	validation's auc: 0.948007
# [224]	validation's auc: 0.948103
# [225]	validation's auc: 0.948187
# [226]	validation's auc: 0.948036
# [227]	validation's auc: 0.948197
# [228]	validation's auc: 0.94812
# [229]	validation's auc: 0.948005
# [230]	validation's auc: 0.94805
# [231]	validation's auc: 0.948016
# [232]	validation's auc: 0.948101
# [233]	validation's auc: 0.94806
# [234]	validation's auc: 0.948146
# [235]	validation's auc: 0.948307
# [236]	validation's auc: 0.94853
# [237]	validation's auc: 0.94844
# [238]	validation's auc: 0.948505
# [239]	validation's auc: 0.948628
# [240]	validation's auc: 0.948608
# [241]	validation's auc: 0.94854
# [242]	validation's auc: 0.948497
# [243]	validation's auc: 0.948497
# [244]	validation's auc: 0.948481
# [245]	validation's auc: 0.948488
# [246]	validation's auc: 0.9485
# [247]	validation's auc: 0.948492
# [248]	validation's auc: 0.948738
# [249]	validation's auc: 0.948719
# [250]	validation's auc: 0.948753
# [251]	validation's auc: 0.948713
# [252]	validation's auc: 0.948842
# [253]	validation's auc: 0.948729
# [254]	validation's auc: 0.94867
# [255]	validation's auc: 0.948692
# [256]	validation's auc: 0.948702
# [257]	validation's auc: 0.948723
# [258]	validation's auc: 0.948801
# [259]	validation's auc: 0.948796
# [260]	validation's auc: 0.948901
# [261]	validation's auc: 0.948906
# [262]	validation's auc: 0.948966
# [263]	validation's auc: 0.948962
# [264]	validation's auc: 0.948936
# [265]	validation's auc: 0.948892
# [266]	validation's auc: 0.948779
# [267]	validation's auc: 0.948756
# [268]	validation's auc: 0.948842
# [269]	validation's auc: 0.949025
# [270]	validation's auc: 0.949059
# [271]	validation's auc: 0.949179
# [272]	validation's auc: 0.949168
# [273]	validation's auc: 0.949202
# [274]	validation's auc: 0.949281
# [275]	validation's auc: 0.94931
# [276]	validation's auc: 0.949299
# [277]	validation's auc: 0.949282
# [278]	validation's auc: 0.949454
# [279]	validation's auc: 0.949543
# [280]	validation's auc: 0.949474
# [281]	validation's auc: 0.949585
# [282]	validation's auc: 0.949603
# [283]	validation's auc: 0.949591
# [284]	validation's auc: 0.949659
# [285]	validation's auc: 0.949693
# [286]	validation's auc: 0.949739
# [287]	validation's auc: 0.949801
# [288]	validation's auc: 0.949864
# [289]	validation's auc: 0.94968
# [290]	validation's auc: 0.94968
# [291]	validation's auc: 0.949772
# [292]	validation's auc: 0.94982
# [293]	validation's auc: 0.949831
# [294]	validation's auc: 0.949832
# [295]	validation's auc: 0.949804
# [296]	validation's auc: 0.949905
# [297]	validation's auc: 0.949995
# [298]	validation's auc: 0.950044
# [299]	validation's auc: 0.949998
# [300]	validation's auc: 0.950041
# [301]	validation's auc: 0.950058
# [302]	validation's auc: 0.950007
# [303]	validation's auc: 0.950066
# [304]	validation's auc: 0.950157
# [305]	validation's auc: 0.950222
# [306]	validation's auc: 0.950196
# [307]	validation's auc: 0.950153
# [308]	validation's auc: 0.95016
# [309]	validation's auc: 0.950166
# [310]	validation's auc: 0.950113
# [311]	validation's auc: 0.95012
# [312]	validation's auc: 0.950151
# [313]	validation's auc: 0.950235
# [314]	validation's auc: 0.950248
# [315]	validation's auc: 0.950229
# [316]	validation's auc: 0.950269
# [317]	validation's auc: 0.950246
# [318]	validation's auc: 0.950313
# [319]	validation's auc: 0.950366
# [320]	validation's auc: 0.950415
# [321]	validation's auc: 0.950543
# [322]	validation's auc: 0.950457
# [323]	validation's auc: 0.950429
# [324]	validation's auc: 0.950481
# [325]	validation's auc: 0.950493
# [326]	validation's auc: 0.950425
# [327]	validation's auc: 0.950356
# [328]	validation's auc: 0.950341
# [329]	validation's auc: 0.950278
# [330]	validation's auc: 0.950344
# [331]	validation's auc: 0.95035
# [332]	validation's auc: 0.950342
# [333]	validation's auc: 0.950382
# [334]	validation's auc: 0.950433
# [335]	validation's auc: 0.95036
# [336]	validation's auc: 0.950266
# [337]	validation's auc: 0.950228
# [338]	validation's auc: 0.950297
# [339]	validation's auc: 0.950323
# [340]	validation's auc: 0.950291
# [341]	validation's auc: 0.95033
# [342]	validation's auc: 0.950297
# [343]	validation's auc: 0.950198
# [344]	validation's auc: 0.950164
# [345]	validation's auc: 0.950204
# [346]	validation's auc: 0.950162
# [347]	validation's auc: 0.950159
# [348]	validation's auc: 0.950228
# [349]	validation's auc: 0.950131
# [350]	validation's auc: 0.950102
# [351]	validation's auc: 0.950078
# [352]	validation's auc: 0.950167
# [353]	validation's auc: 0.950141
# [354]	validation's auc: 0.950051
# [355]	validation's auc: 0.950022
# [356]	validation's auc: 0.950023
# [357]	validation's auc: 0.950103
# [358]	validation's auc: 0.950068
# [359]	validation's auc: 0.950209
# [360]	validation's auc: 0.950189
# [361]	validation's auc: 0.950188
# [362]	validation's auc: 0.950122
# [363]	validation's auc: 0.950093
# [364]	validation's auc: 0.950019
# [365]	validation's auc: 0.950024
# [366]	validation's auc: 0.950016
# [367]	validation's auc: 0.949931
# [368]	validation's auc: 0.949862
# [369]	validation's auc: 0.949817
# [370]	validation's auc: 0.949811
# [371]	validation's auc: 0.94983
# Early stopping, best iteration is:
# [321]	validation's auc: 0.950543
# best roc_auc: 0.9505425783071824
# Accuracy: 89.74%
#               precision    recall  f1-score   support
#
#            0       0.91      0.95      0.93      2803
#            1       0.85      0.75      0.80      1036
#
#     accuracy                           0.90      3839
#    macro avg       0.88      0.85      0.86      3839
# weighted avg       0.90      0.90      0.90      3839
#
# ############################################################################
# rmse: 0.27980237510225475
# ############################################################################
# 2017
# [1]	validation's auc: 0.885423
# Training until validation scores don't improve for 50 rounds
# [2]	validation's auc: 0.8926
# [3]	validation's auc: 0.904232
# [4]	validation's auc: 0.906068
# [5]	validation's auc: 0.908033
# [6]	validation's auc: 0.911178
# [7]	validation's auc: 0.913515
# [8]	validation's auc: 0.916326
# [9]	validation's auc: 0.918325
# [10]	validation's auc: 0.918881
# [11]	validation's auc: 0.921706
# [12]	validation's auc: 0.922071
# [13]	validation's auc: 0.923708
# [14]	validation's auc: 0.92504
# [15]	validation's auc: 0.925617
# [16]	validation's auc: 0.927236
# [17]	validation's auc: 0.92813
# [18]	validation's auc: 0.929326
# [19]	validation's auc: 0.929942
# [20]	validation's auc: 0.931012
# [21]	validation's auc: 0.931797
# [22]	validation's auc: 0.932272
# [23]	validation's auc: 0.933034
# [24]	validation's auc: 0.933431
# [25]	validation's auc: 0.933906
# [26]	validation's auc: 0.934795
# [27]	validation's auc: 0.935592
# [28]	validation's auc: 0.935838
# [29]	validation's auc: 0.936364
# [30]	validation's auc: 0.937045
# [31]	validation's auc: 0.937718
# [32]	validation's auc: 0.938342
# [33]	validation's auc: 0.938817
# [34]	validation's auc: 0.939535
# [35]	validation's auc: 0.939835
# [36]	validation's auc: 0.940149
# [37]	validation's auc: 0.940236
# [38]	validation's auc: 0.94055
# [39]	validation's auc: 0.940719
# [40]	validation's auc: 0.941427
# [41]	validation's auc: 0.941684
# [42]	validation's auc: 0.942264
# [43]	validation's auc: 0.94252
# [44]	validation's auc: 0.942999
# [45]	validation's auc: 0.94329
# [46]	validation's auc: 0.943571
# [47]	validation's auc: 0.944426
# [48]	validation's auc: 0.944495
# [49]	validation's auc: 0.944876
# [50]	validation's auc: 0.945117
# [51]	validation's auc: 0.945365
# [52]	validation's auc: 0.945618
# [53]	validation's auc: 0.945867
# [54]	validation's auc: 0.946021
# [55]	validation's auc: 0.946218
# [56]	validation's auc: 0.946027
# [57]	validation's auc: 0.946311
# [58]	validation's auc: 0.946223
# [59]	validation's auc: 0.946486
# [60]	validation's auc: 0.947234
# [61]	validation's auc: 0.947301
# [62]	validation's auc: 0.947236
# [63]	validation's auc: 0.947467
# [64]	validation's auc: 0.947509
# [65]	validation's auc: 0.948109
# [66]	validation's auc: 0.948309
# [67]	validation's auc: 0.948347
# [68]	validation's auc: 0.94836
# [69]	validation's auc: 0.948307
# [70]	validation's auc: 0.94826
# [71]	validation's auc: 0.948258
# [72]	validation's auc: 0.948356
# [73]	validation's auc: 0.948377
# [74]	validation's auc: 0.948399
# [75]	validation's auc: 0.948465
# [76]	validation's auc: 0.948367
# [77]	validation's auc: 0.94837
# [78]	validation's auc: 0.948503
# [79]	validation's auc: 0.9486
# [80]	validation's auc: 0.948546
# [81]	validation's auc: 0.948703
# [82]	validation's auc: 0.948689
# [83]	validation's auc: 0.948712
# [84]	validation's auc: 0.948876
# [85]	validation's auc: 0.948744
# [86]	validation's auc: 0.94879
# [87]	validation's auc: 0.948802
# [88]	validation's auc: 0.948888
# [89]	validation's auc: 0.948917
# [90]	validation's auc: 0.949027
# [91]	validation's auc: 0.94912
# [92]	validation's auc: 0.949213
# [93]	validation's auc: 0.94918
# [94]	validation's auc: 0.949204
# [95]	validation's auc: 0.949341
# [96]	validation's auc: 0.949289
# [97]	validation's auc: 0.949289
# [98]	validation's auc: 0.949366
# [99]	validation's auc: 0.949477
# [100]	validation's auc: 0.949538
# [101]	validation's auc: 0.949722
# [102]	validation's auc: 0.949692
# [103]	validation's auc: 0.94963
# [104]	validation's auc: 0.949656
# [105]	validation's auc: 0.949749
# [106]	validation's auc: 0.949825
# [107]	validation's auc: 0.950251
# [108]	validation's auc: 0.950249
# [109]	validation's auc: 0.950181
# [110]	validation's auc: 0.950205
# [111]	validation's auc: 0.950171
# [112]	validation's auc: 0.950473
# [113]	validation's auc: 0.95045
# [114]	validation's auc: 0.950521
# [115]	validation's auc: 0.95045
# [116]	validation's auc: 0.950408
# [117]	validation's auc: 0.950337
# [118]	validation's auc: 0.950272
# [119]	validation's auc: 0.950333
# [120]	validation's auc: 0.950523
# [121]	validation's auc: 0.950591
# [122]	validation's auc: 0.950684
# [123]	validation's auc: 0.950655
# [124]	validation's auc: 0.950836
# [125]	validation's auc: 0.950888
# [126]	validation's auc: 0.95101
# [127]	validation's auc: 0.951043
# [128]	validation's auc: 0.951177
# [129]	validation's auc: 0.951176
# [130]	validation's auc: 0.951078
# [131]	validation's auc: 0.950939
# [132]	validation's auc: 0.950963
# [133]	validation's auc: 0.950913
# [134]	validation's auc: 0.951013
# [135]	validation's auc: 0.951032
# [136]	validation's auc: 0.951182
# [137]	validation's auc: 0.951208
# [138]	validation's auc: 0.951268
# [139]	validation's auc: 0.951254
# [140]	validation's auc: 0.951121
# [141]	validation's auc: 0.95107
# [142]	validation's auc: 0.950938
# [143]	validation's auc: 0.951026
# [144]	validation's auc: 0.95102
# [145]	validation's auc: 0.951059
# [146]	validation's auc: 0.951232
# [147]	validation's auc: 0.95127
# [148]	validation's auc: 0.951249
# [149]	validation's auc: 0.951452
# [150]	validation's auc: 0.951406
# [151]	validation's auc: 0.951389
# [152]	validation's auc: 0.951419
# [153]	validation's auc: 0.95148
# [154]	validation's auc: 0.951529
# [155]	validation's auc: 0.951461
# [156]	validation's auc: 0.951475
# [157]	validation's auc: 0.951483
# [158]	validation's auc: 0.951739
# [159]	validation's auc: 0.951826
# [160]	validation's auc: 0.951608
# [161]	validation's auc: 0.951653
# [162]	validation's auc: 0.951694
# [163]	validation's auc: 0.951645
# [164]	validation's auc: 0.951625
# [165]	validation's auc: 0.951745
# [166]	validation's auc: 0.951725
# [167]	validation's auc: 0.951717
# [168]	validation's auc: 0.951938
# [169]	validation's auc: 0.952057
# [170]	validation's auc: 0.952126
# [171]	validation's auc: 0.952206
# [172]	validation's auc: 0.952186
# [173]	validation's auc: 0.952269
# [174]	validation's auc: 0.952551
# [175]	validation's auc: 0.952694
# [176]	validation's auc: 0.952627
# [177]	validation's auc: 0.952606
# [178]	validation's auc: 0.952622
# [179]	validation's auc: 0.952617
# [180]	validation's auc: 0.952721
# [181]	validation's auc: 0.952916
# [182]	validation's auc: 0.952895
# [183]	validation's auc: 0.952987
# [184]	validation's auc: 0.953024
# [185]	validation's auc: 0.953
# [186]	validation's auc: 0.953026
# [187]	validation's auc: 0.952984
# [188]	validation's auc: 0.952918
# [189]	validation's auc: 0.952861
# [190]	validation's auc: 0.952813
# [191]	validation's auc: 0.952845
# [192]	validation's auc: 0.952712
# [193]	validation's auc: 0.952692
# [194]	validation's auc: 0.952629
# [195]	validation's auc: 0.952693
# [196]	validation's auc: 0.952685
# [197]	validation's auc: 0.952637
# [198]	validation's auc: 0.952746
# [199]	validation's auc: 0.9528
# [200]	validation's auc: 0.952797
# [201]	validation's auc: 0.952826
# [202]	validation's auc: 0.952823
# [203]	validation's auc: 0.95278
# [204]	validation's auc: 0.952772
# [205]	validation's auc: 0.952872
# [206]	validation's auc: 0.952795
# [207]	validation's auc: 0.952731
# [208]	validation's auc: 0.952929
# [209]	validation's auc: 0.95285
# [210]	validation's auc: 0.952902
# [211]	validation's auc: 0.952955
# [212]	validation's auc: 0.952976
# [213]	validation's auc: 0.953107
# [214]	validation's auc: 0.953104
# [215]	validation's auc: 0.953138
# [216]	validation's auc: 0.953217
# [217]	validation's auc: 0.953209
# [218]	validation's auc: 0.95316
# [219]	validation's auc: 0.95305
# [220]	validation's auc: 0.953114
# [221]	validation's auc: 0.953102
# [222]	validation's auc: 0.953222
# [223]	validation's auc: 0.953175
# [224]	validation's auc: 0.953163
# [225]	validation's auc: 0.953155
# [226]	validation's auc: 0.953172
# [227]	validation's auc: 0.953045
# [228]	validation's auc: 0.953126
# [229]	validation's auc: 0.953193
# [230]	validation's auc: 0.953128
# [231]	validation's auc: 0.953004
# [232]	validation's auc: 0.952997
# [233]	validation's auc: 0.95293
# [234]	validation's auc: 0.952934
# [235]	validation's auc: 0.952875
# [236]	validation's auc: 0.952968
# [237]	validation's auc: 0.953055
# [238]	validation's auc: 0.953077
# [239]	validation's auc: 0.953074
# [240]	validation's auc: 0.953153
# [241]	validation's auc: 0.953109
# [242]	validation's auc: 0.953045
# [243]	validation's auc: 0.952939
# [244]	validation's auc: 0.952938
# [245]	validation's auc: 0.953063
# [246]	validation's auc: 0.953051
# [247]	validation's auc: 0.953098
# [248]	validation's auc: 0.953113
# [249]	validation's auc: 0.953147
# [250]	validation's auc: 0.953235
# [251]	validation's auc: 0.953221
# [252]	validation's auc: 0.953198
# [253]	validation's auc: 0.953199
# [254]	validation's auc: 0.953149
# [255]	validation's auc: 0.953093
# [256]	validation's auc: 0.953095
# [257]	validation's auc: 0.953246
# [258]	validation's auc: 0.953262
# [259]	validation's auc: 0.953259
# [260]	validation's auc: 0.953227
# [261]	validation's auc: 0.953368
# [262]	validation's auc: 0.953407
# [263]	validation's auc: 0.953442
# ...
# [65]	validation's auc: 0.928206
# [66]	validation's auc: 0.928884
# [67]	validation's auc: 0.929028
# [68]	validation's auc: 0.929495
# [69]	validation's auc: 0.929565
# [70]	validation's auc: 0.929442
# [71]	validation's auc: 0.929924
# [72]	validation's auc: 0.929247
# [73]	validation's auc: 0.929799
# [74]	validation's auc: 0.929558
# [75]	validation's auc: 0.930472
# [76]	validation's auc: 0.930262
# [77]	validation's auc: 0.930188
# [78]	validation's auc: 0.930443
# [79]	validation's auc: 0.930049
# [80]	validation's auc: 0.930448
# [81]	validation's auc: 0.930221
# [82]	validation's auc: 0.930759
# [83]	validation's auc: 0.930682
# [84]	validation's auc: 0.930326
# [85]	validation's auc: 0.92972
# [86]	validation's auc: 0.92982
# [87]	validation's auc: 0.929466
# [88]	validation's auc: 0.929495
# [89]	validation's auc: 0.930095
# [90]	validation's auc: 0.930075
# [91]	validation's auc: 0.930606
# [92]	validation's auc: 0.930238
# [93]	validation's auc: 0.929925
# [94]	validation's auc: 0.930576
# [95]	validation's auc: 0.930176
# [96]	validation's auc: 0.930036
# [97]	validation's auc: 0.930788
# [98]	validation's auc: 0.930384
# [99]	validation's auc: 0.930453
# [100]	validation's auc: 0.931007
# [101]	validation's auc: 0.931144
# [102]	validation's auc: 0.931188
# [103]	validation's auc: 0.931373
# [104]	validation's auc: 0.931619
# [105]	validation's auc: 0.931732
# [106]	validation's auc: 0.931193
# [107]	validation's auc: 0.931036
# [108]	validation's auc: 0.931143
# [109]	validation's auc: 0.930958
# [110]	validation's auc: 0.930938
# [111]	validation's auc: 0.930439
# [112]	validation's auc: 0.930912
# [113]	validation's auc: 0.930788
# [114]	validation's auc: 0.930243
# [115]	validation's auc: 0.930125
# [116]	validation's auc: 0.930741
# [117]	validation's auc: 0.930684
# [118]	validation's auc: 0.930779
# [119]	validation's auc: 0.930712
# [120]	validation's auc: 0.930493
# [121]	validation's auc: 0.930907
# [122]	validation's auc: 0.931161
# [123]	validation's auc: 0.930823
# [124]	validation's auc: 0.931225
# [125]	validation's auc: 0.931882
# [126]	validation's auc: 0.932267
# [127]	validation's auc: 0.932286
# [128]	validation's auc: 0.932341
# [129]	validation's auc: 0.931827
# [130]	validation's auc: 0.931217
# [131]	validation's auc: 0.930459
# [132]	validation's auc: 0.929988
# [133]	validation's auc: 0.929548
# [134]	validation's auc: 0.929961
# [135]	validation's auc: 0.929804
# [136]	validation's auc: 0.93055
# [137]	validation's auc: 0.930847
# [138]	validation's auc: 0.930985
# [139]	validation's auc: 0.931171
# [140]	validation's auc: 0.931322
# [141]	validation's auc: 0.931
# [142]	validation's auc: 0.93148
# [143]	validation's auc: 0.931659
# [144]	validation's auc: 0.932007
# [145]	validation's auc: 0.931989
# [146]	validation's auc: 0.931619
# [147]	validation's auc: 0.93138
# [148]	validation's auc: 0.931357
# [149]	validation's auc: 0.931814
# [150]	validation's auc: 0.932319
# [151]	validation's auc: 0.932926
# [152]	validation's auc: 0.932674
# [153]	validation's auc: 0.932568
# [154]	validation's auc: 0.932173
# [155]	validation's auc: 0.932521
# [156]	validation's auc: 0.933051
# [157]	validation's auc: 0.932967
# [158]	validation's auc: 0.932531
# [159]	validation's auc: 0.932214
# [160]	validation's auc: 0.932058
# [161]	validation's auc: 0.93211
# [162]	validation's auc: 0.931994
# [163]	validation's auc: 0.93164
# [164]	validation's auc: 0.93189
# [165]	validation's auc: 0.932471
# [166]	validation's auc: 0.932278
# [167]	validation's auc: 0.932448
# [168]	validation's auc: 0.932232
# [169]	validation's auc: 0.932408
# [170]	validation's auc: 0.9323
# [171]	validation's auc: 0.932086
# [172]	validation's auc: 0.932441
# [173]	validation's auc: 0.932273
# [174]	validation's auc: 0.931814
# [175]	validation's auc: 0.931341
# [176]	validation's auc: 0.931017
# [177]	validation's auc: 0.930944
# [178]	validation's auc: 0.931294
# [179]	validation's auc: 0.93142
# [180]	validation's auc: 0.931593
# [181]	validation's auc: 0.931498
# [182]	validation's auc: 0.931795
# [183]	validation's auc: 0.931439
# [184]	validation's auc: 0.931822
# [185]	validation's auc: 0.931521
# [186]	validation's auc: 0.93144
# [187]	validation's auc: 0.931335
# [188]	validation's auc: 0.932034
# [189]	validation's auc: 0.932258
# [190]	validation's auc: 0.932087
# [191]	validation's auc: 0.932671
# [192]	validation's auc: 0.932627
# [193]	validation's auc: 0.93268
# [194]	validation's auc: 0.932644
# [195]	validation's auc: 0.932759
# [196]	validation's auc: 0.932976
# [197]	validation's auc: 0.933027
# [198]	validation's auc: 0.932964
# [199]	validation's auc: 0.93342
# [200]	validation's auc: 0.933295
# [201]	validation's auc: 0.933033
# [202]	validation's auc: 0.932544
# [203]	validation's auc: 0.932477
# [204]	validation's auc: 0.932223
# [205]	validation's auc: 0.932472
# [206]	validation's auc: 0.932427
# [207]	validation's auc: 0.932891
# [208]	validation's auc: 0.93294
# [209]	validation's auc: 0.932837
# [210]	validation's auc: 0.933018
# [211]	validation's auc: 0.933058
# [212]	validation's auc: 0.932845
# [213]	validation's auc: 0.932513
# [214]	validation's auc: 0.933274
# [215]	validation's auc: 0.933336
# [216]	validation's auc: 0.933636
# [217]	validation's auc: 0.933445
# [218]	validation's auc: 0.933594
# [219]	validation's auc: 0.93382
# [220]	validation's auc: 0.933778
# [221]	validation's auc: 0.934255
# [222]	validation's auc: 0.9342
# [223]	validation's auc: 0.934478
# [224]	validation's auc: 0.93491
# [225]	validation's auc: 0.93513
# [226]	validation's auc: 0.935009
# [227]	validation's auc: 0.934736
# [228]	validation's auc: 0.935039
# [229]	validation's auc: 0.93447
# [230]	validation's auc: 0.934728
# [231]	validation's auc: 0.935116
# [232]	validation's auc: 0.935173
# [233]	validation's auc: 0.935516
# [234]	validation's auc: 0.935466
# [235]	validation's auc: 0.935263
# [236]	validation's auc: 0.935174
# [237]	validation's auc: 0.935761
# [238]	validation's auc: 0.935752
# [239]	validation's auc: 0.935368
# [240]	validation's auc: 0.935278
# [241]	validation's auc: 0.935136
# [242]	validation's auc: 0.935268
# [243]	validation's auc: 0.935192
# [244]	validation's auc: 0.935173
# [245]	validation's auc: 0.934904
# [246]	validation's auc: 0.934989
# [247]	validation's auc: 0.935446
# [248]	validation's auc: 0.935183
# [249]	validation's auc: 0.934905
# [250]	validation's auc: 0.934996
# [251]	validation's auc: 0.935248
# [252]	validation's auc: 0.935257
# [253]	validation's auc: 0.935161
# [254]	validation's auc: 0.934883
# [255]	validation's auc: 0.93507
# [256]	validation's auc: 0.935527
# [257]	validation's auc: 0.935561
# [258]	validation's auc: 0.935641
# [259]	validation's auc: 0.935674
# [260]	validation's auc: 0.935473
# [261]	validation's auc: 0.935255
# [262]	validation's auc: 0.935607
# [263]	validation's auc: 0.935459
# [264]	validation's auc: 0.935445
# [265]	validation's auc: 0.935352
# [266]	validation's auc: 0.935124
# [267]	validation's auc: 0.935286
# [268]	validation's auc: 0.935269
# [269]	validation's auc: 0.935032
# [270]	validation's auc: 0.934804
# [271]	validation's auc: 0.934599
# [272]	validation's auc: 0.93455
# [273]	validation's auc: 0.934309
# [274]	validation's auc: 0.93402
# [275]	validation's auc: 0.933914
# [276]	validation's auc: 0.933936
# [277]	validation's auc: 0.934008
# [278]	validation's auc: 0.933902
# [279]	validation's auc: 0.933749
# [280]	validation's auc: 0.933836
# [281]	validation's auc: 0.934163
# [282]	validation's auc: 0.934323
# [283]	validation's auc: 0.934646
# [284]	validation's auc: 0.934669
# [285]	validation's auc: 0.934583
# [286]	validation's auc: 0.934818
# [287]	validation's auc: 0.93471
# Early stopping, best iteration is:
# [237]	validation's auc: 0.935761
# best roc_auc: 0.9357611649489823
# Accuracy: 91.19%
#               precision    recall  f1-score   support
#
#            0       0.93      0.97      0.95      2002
#            1       0.81      0.67      0.73       439
#
#     accuracy                           0.91      2441
#    macro avg       0.87      0.82      0.84      2441
# weighted avg       0.91      0.91      0.91      2441
#
# ############################################################################
# rmse: 0.2619611467518818
# ############################################################################
# 2003
# [1]	validation's auc: 0.890073
# Training until validation scores don't improve for 50 rounds
# [2]	validation's auc: 0.894364
# [3]	validation's auc: 0.90143
# [4]	validation's auc: 0.899243
# [5]	validation's auc: 0.904476
# [6]	validation's auc: 0.903223
# [7]	validation's auc: 0.904313
# [8]	validation's auc: 0.906856
# [9]	validation's auc: 0.909137
# [10]	validation's auc: 0.912518
# [11]	validation's auc: 0.917392
# [12]	validation's auc: 0.917871
# [13]	validation's auc: 0.922105
# [14]	validation's auc: 0.922795
# [15]	validation's auc: 0.924599
# [16]	validation's auc: 0.925587
# [17]	validation's auc: 0.926298
# [18]	validation's auc: 0.925042
# [19]	validation's auc: 0.926379
# [20]	validation's auc: 0.926751
# [21]	validation's auc: 0.927289
# [22]	validation's auc: 0.927967
# [23]	validation's auc: 0.928633
# [24]	validation's auc: 0.929126
# [25]	validation's auc: 0.92905
# [26]	validation's auc: 0.928403
# [27]	validation's auc: 0.929133
# [28]	validation's auc: 0.929093
# [29]	validation's auc: 0.929156
# [30]	validation's auc: 0.928901
# [31]	validation's auc: 0.928558
# [32]	validation's auc: 0.927999
# [33]	validation's auc: 0.928281
# [34]	validation's auc: 0.928911
# [35]	validation's auc: 0.92903
# [36]	validation's auc: 0.92845
# [37]	validation's auc: 0.928427
# [38]	validation's auc: 0.928803
# [39]	validation's auc: 0.928785
# [40]	validation's auc: 0.928787
# [41]	validation's auc: 0.92875
# [42]	validation's auc: 0.929302
# [43]	validation's auc: 0.930007
# [44]	validation's auc: 0.929915
# [45]	validation's auc: 0.929878
# [46]	validation's auc: 0.930133
# [47]	validation's auc: 0.930217
# [48]	validation's auc: 0.929868
# [49]	validation's auc: 0.930726
# [50]	validation's auc: 0.930154
# [51]	validation's auc: 0.930635
# [52]	validation's auc: 0.930859
# [53]	validation's auc: 0.930799
# [54]	validation's auc: 0.930743
# [55]	validation's auc: 0.93131
# [56]	validation's auc: 0.931744
# [57]	validation's auc: 0.931169
# [58]	validation's auc: 0.931154
# [59]	validation's auc: 0.930643
# [60]	validation's auc: 0.931105
# [61]	validation's auc: 0.931499
# [62]	validation's auc: 0.930591
# [63]	validation's auc: 0.931622
# [64]	validation's auc: 0.931877
# [65]	validation's auc: 0.931809
# [66]	validation's auc: 0.931516
# [67]	validation's auc: 0.931957
# [68]	validation's auc: 0.931705
# [69]	validation's auc: 0.932085
# [70]	validation's auc: 0.93146
# [71]	validation's auc: 0.93154
# [72]	validation's auc: 0.931407
# [73]	validation's auc: 0.931187
# [74]	validation's auc: 0.931105
# [75]	validation's auc: 0.931048
# [76]	validation's auc: 0.931541
# [77]	validation's auc: 0.931401
# [78]	validation's auc: 0.931964
# [79]	validation's auc: 0.93158
# [80]	validation's auc: 0.93126
# [81]	validation's auc: 0.931164
# [82]	validation's auc: 0.931932
# [83]	validation's auc: 0.931568
# [84]	validation's auc: 0.931056
# [85]	validation's auc: 0.930692
# [86]	validation's auc: 0.930614
# [87]	validation's auc: 0.930726
# [88]	validation's auc: 0.931185
# [89]	validation's auc: 0.931255
# [90]	validation's auc: 0.931561
# [91]	validation's auc: 0.931376
# [92]	validation's auc: 0.93151
# [93]	validation's auc: 0.931421
# [94]	validation's auc: 0.930807
# [95]	validation's auc: 0.930605
# [96]	validation's auc: 0.931236
# [97]	validation's auc: 0.931564
# [98]	validation's auc: 0.932382
# [99]	validation's auc: 0.932572
# [100]	validation's auc: 0.932841
# [101]	validation's auc: 0.932899
# [102]	validation's auc: 0.933092
# [103]	validation's auc: 0.933224
# [104]	validation's auc: 0.933134
# [105]	validation's auc: 0.933555
# [106]	validation's auc: 0.933486
# [107]	validation's auc: 0.933929
# [108]	validation's auc: 0.933843
# [109]	validation's auc: 0.933782
# [110]	validation's auc: 0.934094
# [111]	validation's auc: 0.934317
# [112]	validation's auc: 0.934406
# [113]	validation's auc: 0.93437
# [114]	validation's auc: 0.933908
# [115]	validation's auc: 0.934177
# [116]	validation's auc: 0.934461
# [117]	validation's auc: 0.934065
# [118]	validation's auc: 0.93417
# [119]	validation's auc: 0.93432
# [120]	validation's auc: 0.934629
# [121]	validation's auc: 0.934468
# [122]	validation's auc: 0.934624
# [123]	validation's auc: 0.934772
# [124]	validation's auc: 0.934978
# [125]	validation's auc: 0.935121
# [126]	validation's auc: 0.93503
# [127]	validation's auc: 0.93503
# [128]	validation's auc: 0.934562
# [129]	validation's auc: 0.934823
# [130]	validation's auc: 0.934489
# [131]	validation's auc: 0.93461
# [132]	validation's auc: 0.934865
# [133]	validation's auc: 0.934851
# [134]	validation's auc: 0.934966
# [135]	validation's auc: 0.934862
# [136]	validation's auc: 0.935052
# [137]	validation's auc: 0.93527
# [138]	validation's auc: 0.935155
# [139]	validation's auc: 0.934876
# [140]	validation's auc: 0.93503
# [141]	validation's auc: 0.93531
# [142]	validation's auc: 0.935306
# [143]	validation's auc: 0.935522
# [144]	validation's auc: 0.93495
# [145]	validation's auc: 0.934517
# [146]	validation's auc: 0.934894
# [147]	validation's auc: 0.935107
# [148]	validation's auc: 0.935005
# [149]	validation's auc: 0.935101
# [150]	validation's auc: 0.934817
# [151]	validation's auc: 0.93474
# [152]	validation's auc: 0.934446
# [153]	validation's auc: 0.934568
# [154]	validation's auc: 0.934331
# [155]	validation's auc: 0.934154
# [156]	validation's auc: 0.934094
# [157]	validation's auc: 0.933719
# [158]	validation's auc: 0.933626
# [159]	validation's auc: 0.933731
# [160]	validation's auc: 0.933447
# [161]	validation's auc: 0.933263
# [162]	validation's auc: 0.93345
# [163]	validation's auc: 0.933581
# [164]	validation's auc: 0.933499
# [165]	validation's auc: 0.933562
# [166]	validation's auc: 0.934173
# [167]	validation's auc: 0.934208
# [168]	validation's auc: 0.933925
# [169]	validation's auc: 0.934007
# [170]	validation's auc: 0.934121
# [171]	validation's auc: 0.934027
# [172]	validation's auc: 0.934175
# [173]	validation's auc: 0.934391
# [174]	validation's auc: 0.934184
# [175]	validation's auc: 0.934402
# [176]	validation's auc: 0.934552
# [177]	validation's auc: 0.934789
# [178]	validation's auc: 0.934576
# [179]	validation's auc: 0.934352
# [180]	validation's auc: 0.934636
# [181]	validation's auc: 0.934586
# [182]	validation's auc: 0.935118
# [183]	validation's auc: 0.934943
# [184]	validation's auc: 0.935031
# [185]	validation's auc: 0.935198
# [186]	validation's auc: 0.93489
# [187]	validation's auc: 0.934816
# [188]	validation's auc: 0.934781
# [189]	validation's auc: 0.934953
# [190]	validation's auc: 0.934709
# [191]	validation's auc: 0.935136
# [192]	validation's auc: 0.93502
# [193]	validation's auc: 0.935222
# Early stopping, best iteration is:
# [143]	validation's auc: 0.935522
# best roc_auc: 0.9355217916420302
# Accuracy: 90.23%
#               precision    recall  f1-score   support
#
#            0       0.93      0.95      0.94      1871
#            1       0.75      0.70      0.72       421
#
#     accuracy                           0.90      2292
#    macro avg       0.84      0.82      0.83      2292
# weighted avg       0.90      0.90      0.90      2292
#
# ############################################################################
# rmse: 0.2642218292265389
# Accuracy 2021 to 2003 [89.1711229946524, 89.04939422180802, 87.7082830234243, 89.7369106538161, 90.09928295642582, 90.43676848415643, 90.12418687167356, 89.70140158439975, 90.87227414330218, 90.62702003878475, 90.51926298157454, 89.43661971830986, 89.55491744436468, 90.48332708879731, 91.16190476190476, 90.08168028004667, 90.43650793650794, 91.19213437115936, 90.22687609075044]
#
#
# AUC 2021 to 2003 [0.9531493522362336, 0.9525186911511104, 0.9429531152559669, 0.9505425783071824, 0.9560173732317327, 0.9538396485650037, 0.9499822630301995, 0.9483528467327522, 0.9532142529565446, 0.9506677991156525, 0.9458627133242822, 0.9388040564168317, 0.928272320751857, 0.9355320756394019, 0.950235289339159, 0.9459214575493646, 0.9377390321830873, 0.9357611649489823, 0.9355217916420302]
#
#
# recall score 2021 to 2003 [0.7808, 0.7576243980738363, 0.7243642329778507, 0.749034749034749, 0.738015607580825, 0.7382953181272509, 0.7532299741602068, 0.6813922356091031, 0.7461645746164575, 0.7340267459138187, 0.7320574162679426, 0.6078098471986417, 0.5928571428571429, 0.666023166023166, 0.6614173228346457, 0.6016427104722792, 0.6445396145610278, 0.6651480637813212, 0.6959619952494062]
#
#
# average recall of 1:  0.6984423744915619
