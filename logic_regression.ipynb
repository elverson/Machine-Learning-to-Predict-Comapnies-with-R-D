# %% [markdown]
# ### Logistic Regression

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.ticker import PercentFormatter
import matplotlib.ticker as mtick
# %matplotlib inline   
### The resulting plots will then also be shown in the notebook document.

from random import sample
import seaborn as sns
sns.set()
from functools import reduce
from sklearn import metrics
from sklearn import preprocessing
from sklearn.metrics import classification_report
from sklearn.metrics import accuracy_score
from sklearn.datasets import make_classification
from sklearn.model_selection import train_test_split
from sklearn.model_selection import StratifiedShuffleSplit
from sklearn.utils import resample
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import LabelEncoder
from sklearn.feature_selection import SelectFromModel
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
from sklearn.metrics import recall_score

# import warnings filter
from warnings import simplefilter
# ignore all future warnings
simplefilter(action='ignore', category=FutureWarning)

# %%
list_year = ['2021','2020','2019','2018','2017','2016','2015','2014']
accuracy_list = []
auc_list = []
recall_list = []

def Average(lst):
    return reduce(lambda a, b: a + b, lst) / len(lst)

for year in list_year:
    print('############################################################################')
    print('year'+ year + '\n')
    df_ratios = pd.read_csv(year+'.csv')
    df_ratios

    # Display the structure
    #df_ratios.info()

    # Normalization
    from sklearn import preprocessing
    min_max_scaler = preprocessing.MinMaxScaler()

    for i in df_ratios.columns[3:-12]:
        df_ratios[i] = min_max_scaler.fit_transform(df_ratios[[i]].to_numpy())*1000
        df_ratios[i] = df_ratios[i].apply(lambda x: np.log10(x + 0.01))
        ### this normalization is arbitrary, but should put all nos. in comparable basis of the same magnitude - can see the
        ###   describe statistics below
    
    # Statistical summary 
    #print(df_ratios.head(10))
    #df_ratios.describe()    

    df_ratios_new=df_ratios

    #df_ratios_new.head(20)
    ### note the gicdesc is now transformed to a number instead of name

    Train, Test = train_test_split(df_ratios_new, test_size=0.4, random_state=43)
    X_train, y_train = Train.iloc[:,3:-1], Train.iloc[:,-1]
    X_test, y_test = Test.iloc[:,3:-1], Test.iloc[:,-1]

    y_test.shape[0]  ### sample size of y-test is 2774 x .25


    from sklearn.linear_model import LogisticRegression
    from sklearn import metrics
    LR = LogisticRegression()
    Lresult = LR.fit(X_train, y_train)

    y_pred = LR.predict(X_test)
    Accuracy_LR = metrics.accuracy_score(y_test, y_pred)
    print("LR Accuracy:",Accuracy_LR)

    from sklearn.metrics import confusion_matrix
    confusion_matrix = confusion_matrix(y_test, y_pred)
    cm_display = metrics.ConfusionMatrixDisplay(confusion_matrix = confusion_matrix, display_labels = [0, 1])
    cm_display.plot()
    plt.show()
    recallScore = recall_score(y_test, y_pred)
    from sklearn.metrics import classification_report
    print(classification_report(y_test, y_pred))
    from sklearn.metrics import roc_auc_score
    from sklearn.metrics import roc_curve
    logit_roc_auc = roc_auc_score(y_test, LR.predict(X_test))
    print('AUC:',logit_roc_auc)
    fpr, tpr, thresholds = roc_curve(y_test, LR.predict_proba(X_test)[:,1])
    plt.figure()
    plt.plot(fpr, tpr, label='Logistic Regression (area = %0.2f)' % logit_roc_auc)
    plt.plot([0, 1], [0, 1],'r--')
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('Logistic Regression AUC')
    plt.legend(loc="lower right")
    plt.savefig('Log_ROC')
    plt.show()


    values = df_ratios[['Unnamed: 0', 'index', 'company', 'IQ_TOTAL_ASSETS', 'IQ_RETURN_ASSETS', 'IQ_RETURN_CAPITAL', 'IQ_RETURN_EQUITY', 'IQ_RETURN_INVESTED_CAPITAL', 'IQ_RETURN_COMMON_EQUITY', 'IQ_GROSS_MARGIN', 'IQ_EBITDA_MARGIN', 'IQ_EARNING_CO_MARGIN', 'IQ_NI_MARGIN', 'IQ_LFCF_MARGIN', 'IQ_FIXED_ASSET_TURNS', 'IQ_AR_TURNS', 'IQ_CURRENT_RATIO', 'IQ_QUICK_RATIO', 'IQ_DAYS_SALES_OUT', 'IQ_DAYS_PAYABLE_OUT', 'IQ_CFO_CURRENT_LIAB', 'IQ_TOTAL_DEBT_EQUITY', 'IQ_TOTAL_DEBT_CAPITAL', 'IQ_LT_DEBT_EQUITY', 'IQ_LT_DEBT_CAPITAL', 'IQ_TOTAL_LIAB_TOTAL_ASSETS', 'IQ_EBITDA_CAPEX_INT', 'IQ_Z_SCORE', 'IQ_CAPEX_PCT_REV', 'IQ_TOTAL_REV_1YR_ANN_GROWTH', 'IQ_GP_1YR_ANN_GROWTH', 'IQ_EBITDA_1YR_ANN_GROWTH', 'IQ_ACCT_RECV_1YR_ANN_GROWTH', 'IQ_NPPE_1YR_ANN_GROWTH', 'IQ_COMMON_EQUITY_1YR_ANN_GROWTH', 'IQ_TOTAL_ASSETS_1YR_ANN_GROWTH', 'IQ_CFO_1YR_ANN_GROWTH', 'IQ_CAPEX_1YR_ANN_GROWTH', 'IQ_TOTAL_REV_2YR_ANN_CAGR', 'IQ_GP_2YR_ANN_CAGR', 'IQ_EBITDA_2YR_ANN_CAGR', 'IQ_ACCT_RECV_2YR_ANN_CAGR', 'IQ_NPPE_2YR_ANN_CAGR', 'IQ_COMMON_EQUITY_2YR_ANN_CAGR', 'IQ_TOTAL_ASSETS_2YR_ANN_CAGR', 'IQ_TOTAL_REV_3YR_ANN_CAGR', 'IQ_GP_3YR_ANN_CAGR', 'IQ_EBITDA_3YR_ANN_CAGR', 'IQ_ACCT_RECV_3YR_ANN_CAGR', 'IQ_NPPE_3YR_ANN_CAGR', 'IQ_COMMON_EQUITY_3YR_ANN_CAGR', 'IQ_TOTAL_ASSETS_3YR_ANN_CAGR', 'industry_Communication Services', 'industry_Consumer Discretionary', 'industry_Consumer Staples', 'industry_Energy', 'industry_Financials', 'industry_Health Care', 'industry_Industrials', 'industry_Information Technology', 'industry_Materials', 'industry_Real Estate', 'industry_Utilities', 'RnD_OVER_TA_CAT']]
    correlation = values.corr()
    correlation_df = pd.DataFrame(data = correlation)
    correlation_df.to_csv(year+'corr.csv')
    accuracy_list.append(Accuracy_LR)
    auc_list.append(logit_roc_auc)
    recall_list.append(recallScore)
    print('############################################################################')


    
print('Accuracy 2021 to 2014', accuracy_list)
print('')
print('')
print('AUC 2021 to 2014', auc_list)
print('')
print('')
print('recall score 2021 to 2014', recall_list)
print('')
print('')
average_recall = Average(recall_list)
print('average recall of 1: ', average_recall)
# Out:
# ############################################################################
# year2021
#
# LR Accuracy: 0.819371727748691
# C:\Users\lixue\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
#               precision    recall  f1-score   support
#
#            0       0.84      0.92      0.88       795
#            1       0.76      0.60      0.67       351
#
#     accuracy                           0.82      1146
#    macro avg       0.80      0.76      0.77      1146
# weighted avg       0.81      0.82      0.81      1146
#
# AUC: 0.7584314357899263
# ############################################################################
# ############################################################################
# year2020
#
# LR Accuracy: 0.8208255159474672
# C:\Users\lixue\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
#               precision    recall  f1-score   support
#
#            0       0.84      0.92      0.88       745
#            1       0.75      0.60      0.67       321
#
#     accuracy                           0.82      1066
#    macro avg       0.80      0.76      0.77      1066
# weighted avg       0.82      0.82      0.81      1066
#
# AUC: 0.7583411737648706
# ############################################################################
# ############################################################################
# year2019
# C:\Users\lixue\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LR Accuracy: 0.844131455399061
#               precision    recall  f1-score   support
#
#            0       0.87      0.93      0.90       777
#            1       0.77      0.61      0.68       288
#
#     accuracy                           0.84      1065
#    macro avg       0.82      0.77      0.79      1065
# weighted avg       0.84      0.84      0.84      1065
#
# AUC: 0.7708065208065208
# ############################################################################
# ############################################################################
# year2018
#
# LR Accuracy: 0.819704433497537
# C:\Users\lixue\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
#               precision    recall  f1-score   support
#
#            0       0.85      0.91      0.88       739
#            1       0.71      0.57      0.63       276
#
#     accuracy                           0.82      1015
#    macro avg       0.78      0.74      0.76      1015
# weighted avg       0.81      0.82      0.81      1015
#
# AUC: 0.7399835265046774
# ############################################################################
# ############################################################################
# year2017
#
# LR Accuracy: 0.8387423935091278
# C:\Users\lixue\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
#               precision    recall  f1-score   support
#
#            0       0.85      0.95      0.89       709
#            1       0.81      0.56      0.66       277
#
#     accuracy                           0.84       986
#    macro avg       0.83      0.75      0.78       986
# weighted avg       0.84      0.84      0.83       986
#
# AUC: 0.7536903046442592
# ############################################################################
# ############################################################################
# year2016
#
# LR Accuracy: 0.8354430379746836
# C:\Users\lixue\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
#               precision    recall  f1-score   support
#
#            0       0.86      0.93      0.89       697
#            1       0.74      0.59      0.65       251
#
#     accuracy                           0.84       948
#    macro avg       0.80      0.76      0.77       948
# weighted avg       0.83      0.84      0.83       948
#
# AUC: 0.7555259592905279
# ############################################################################
# ############################################################################
# year2015
#
# LR Accuracy: 0.8388829215896885
# C:\Users\lixue\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
#               precision    recall  f1-score   support
#
#            0       0.88      0.91      0.90       700
#            1       0.70      0.61      0.65       231
#
#     accuracy                           0.84       931
#    macro avg       0.79      0.76      0.77       931
# weighted avg       0.83      0.84      0.83       931
#
# AUC: 0.7623376623376623
# ############################################################################
# ############################################################################
# year2014
#
# LR Accuracy: 0.8384279475982532
# C:\Users\lixue\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
#               precision    recall  f1-score   support
#
#            0       0.85      0.94      0.89       651
#            1       0.79      0.60      0.68       265
#
#     accuracy                           0.84       916
#    macro avg       0.82      0.77      0.79       916
# weighted avg       0.83      0.84      0.83       916
#
# AUC: 0.7677419354838712
# ############################################################################
# Accuracy 2021 to 2014 [0.819371727748691, 0.8208255159474672, 0.844131455399061, 0.819704433497537, 0.8387423935091278, 0.8354430379746836, 0.8388829215896885, 0.8384279475982532]
#
#
# AUC 2021 to 2014 [0.7584314357899263, 0.7583411737648706, 0.7708065208065208, 0.7399835265046774, 0.7536903046442592, 0.7555259592905279, 0.7623376623376623, 0.7677419354838712]
#
#
# recall score 2021 to 2014 [0.6011396011396012, 0.6012461059190031, 0.6111111111111112, 0.5652173913043478, 0.5595667870036101, 0.5856573705179283, 0.6103896103896104, 0.6]
#
#
# average recall of 1:  0.5917909971731514
