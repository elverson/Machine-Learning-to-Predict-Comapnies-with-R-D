# %%
import pandas as pd
import numpy as np
import os

# %%
path = r'C:\\Users\\lixue\\OneDrive\\Desktop\\smu\\MQF\\Quantitative Research\\project_part2\\'
fy2022=pd.read_excel(path+'fy2022_no_only.xlsx',header=1)
fy2021=pd.read_excel(path+'fy2021_no_only.xlsx',header=1)
fy2020=pd.read_excel(path+'fy2020_no_only.xlsx',header=1)
fy2019=pd.read_excel(path+'fy2019_no_only.xlsx',header=1)
fy2018=pd.read_excel(path+'fy2018_no_only.xlsx',header=1)
fy2017=pd.read_excel(path+'fy2017_no_only.xlsx',header=1)
fy2016=pd.read_excel(path+'fy2016_no_only.xlsx',header=1)
fy2015=pd.read_excel(path+'fy2015_no_only.xlsx',header=1)
fy2014=pd.read_excel(path+'fy2014_no_only.xlsx',header=1)
fy2013=pd.read_excel(path+'fy2013_no_only.xlsx',header=1)
fy2012=pd.read_excel(path+'fy2012_no_only.xlsx',header=1)
fy2011=pd.read_excel(path+'fy2011_no_only.xlsx',header=1)
fy2010=pd.read_excel(path+'fy2010_no_only.xlsx',header=1)
fy2009=pd.read_excel(path+'fy2009_no_only.xlsx',header=1)
fy2008=pd.read_excel(path+'fy2008_no_only.xlsx',header=1)
fy2007=pd.read_excel(path+'fy2007_no_only.xlsx',header=1)
fy2006=pd.read_excel(path+'fy2006_no_only.xlsx',header=1)
fy2005=pd.read_excel(path+'fy2005_no_only.xlsx',header=1)
fy2004=pd.read_excel(path+'fy2004_no_only.xlsx',header=1)
fy2003=pd.read_excel(path+'fy2003_no_only_new.xlsx',header=1)
fy2002=pd.read_excel(path+'fy2002_no_only.xlsx',header=1)
fy2001=pd.read_excel(path+'fy2001_no_only.xlsx',header=1)
fy2000=pd.read_excel(path+'fy2000_no_only.xlsx',header=1)

# %%
print(fy2003.head(30))
# Out:
#        Unnamed: 0   period  IQ_RD_EXP                industry  \
# 0       NYSE:GRMN  FQ42003     13.571  Consumer Discretionary
# 1        NYSE:TPR  FQ42003      0.000  Consumer Discretionary
# 2   NasdaqGS:EQIX  FQ42003      0.000             Real Estate
# 3   NasdaqGS:ILMN  FQ42003      5.629             Health Care
# 4        NYSE:CRL  FQ42003      0.000             Health Care
# 5   NasdaqGS:ISRG  FQ42003      4.733             Health Care
# 6     NasdaqGS:ON  FQ42003     24.000  Information Technology
# 7        NYSE:MET  FQ42003      0.000              Financials
# 8         NYSE:EW  FQ42003     19.000             Health Care
# 9        NYSE:PKG  FQ42003      0.000               Materials
# 10       NYSE:TDY  FQ42003      0.000  Information Technology
# 11         NYSE:A  FQ42003    218.000             Health Care
# 12       NYSE:UPS  FQ42003      0.000             Industrials
# 13  NasdaqGS:AKAM  FQ42003      2.909  Information Technology
# ...

# %%
all_year = pd.concat([fy2022,fy2021,fy2020,fy2019,fy2018,fy2017,fy2016,fy2015,fy2014,fy2013,fy2012,fy2011,fy2010,fy2009,fy2008,fy2007,fy2006,fy2005,fy2004,fy2003,fy2002,fy2001,fy2000],axis=0)

# %%
all_year.to_csv('C:\\Users\\lixue\\OneDrive\\Desktop\\smu\\MQF\\Quantitative Research\\project_part2\\all_year.csv')
